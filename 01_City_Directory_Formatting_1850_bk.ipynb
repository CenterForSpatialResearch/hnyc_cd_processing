# %%
# !ls "input/1850/GNA_bk_1850.txt"
# Out:
# input/1850/GNA_bk_1850.txt

# %%
#load data
import glob # import glob to retrieve files/pathnames matching a specified pattern
file_path = "input/1850/GNA_bk_1850.txt"
with open(file_path, 'r', encoding="cp1252") as f: # The encoding was different from the previous 2
  data = f.readlines()

# %%
import pandas as pd
pd.DataFrame(data).shape
# Out:
# (17089, 1)

# %% [markdown]
# There are 17,089 rows

# %%
data[0:10]
# Out:
# ['HE ARNES’\n',
#  'BROOKLYN CITY\n',
#  'DIRECTORY.\n',
#  '1850-1851.\n',
#  'NOTE.—Names having a * are the names of colored people\n',
#  'Abbreviationsh. stands for house, n, for near, c. for corner, op. for\n',
#  'opposite,b. for between, The precise location of residences thus de-\n',
#  'scribed, may be ascertained by reference to the SHEET DIREOTORY.\n',
#  'A\n',
#  'Abberly Richard, shoemaker 168 Hudson av\n']

# %% [markdown]
# ## Clean Data

# %%
# Remove Headers from data
header = ['BROOKLYN DIRECTORY.\n', 'BROOKLYN DIRECTORY,\n', 'BROOKLYN DIR-ECTORY,\n', 'BROOKLYN DIRECTOE.Y.\n', 'BROOKLYN DIBECTORY.\n', 'BROOKLYN DIR-ECTORY\n']
data = [entry for entry in data if entry not in header]

# Remove \n
data = [entry.replace('\n', '') for entry in data]

# Remove \t
data = [entry.replace('\t', ' ') for entry in data]

# Remove Blanks
data = [entry for entry in data if entry != ' ']

# Remove Page Numbers
import re
data = [entry for entry in data if not re.search('^[0-9]+$', entry)]

# %%
len(data)
# Out:
# 16081

# %%
data
# Out:
# ['A',
#  'Abberly Richard, shoemaker 168 Hudson av',
#  'Abberly Samuel, mason Dean n Vanderbilt av',
#  'Abbey A C, carpenter 82 Poplar',
#  'ABBES HORATIO G, Columbia Institute for the education of',
#  'boys 75 Columbia',
#  'Abbey W S, merchant NYh Union n Court',
#  'Abbott Abraham, marble sawyer Pacific n Boerum',
#  'Abbott Daniel, 25 Front ',
#  'Abbott Francis H, merchant 141 Front NYh Joralemon n Court',
#  'Abbott H B, milkman Kent av north',
#  'Abbott James, laborer Bond c State ',
#  'Abbott John D, merchant 295.5 Pearl NYh 362 Atlantic n Hoyt',
#  'Abbott Moses, furrier 74 Concord',
#  'Abbott Samuel D, butcher Myrtle c Jay h 115 Johnson',
#  'Abburty John, shoemaker 261 Marshall',
#  'Abel E L, accountant 301 Gold',
#  'Aber Hiram, sash and blind maker 33 Prince',
#  'Aber Smith M, sashmaker 288 Hudson av',
#  'Abercrombie George, shoemaker Navy c Sands',
#  'Abercrombie John, shoemaker 116 Concord',
#  'Aborn Robert W, merchant NYh 180 Henry',
#  'Abraham David, capmaker 5 York',
#  'Abrahams Joseph, laborer 3 Kelsey’s alley',
#  'Abrahams Jane, widow of James, 95 Concord',
#  '*Abrahams Thompson, seaman Clark’s alley n York',
#  'Abraham Patrick, laborer State c Smith',
#  'Abrams Joseph, sash.and blind maker 14 James & 59 Pearl',
#  'Abrams Valentine, carpenter 159 Gold',
#  '*Abrams Thomas, laborer 74 Jay',
#  'Acker Agnes, widow 97 Prospect',
#  'Acker George AV, ship joiner 109 Gold',
#  'Acker Matilda, widow Hudson c Myrtle av',
#  'Acker Matilda, widow of Henry 267 Hudson av',
#  'Ackerman Catherine, 145 York',
#  'Ackerman James M, printer 90 Washington',
#  'Ackerman James, Navy c Bolivar',
#  'Ackerman John M, builder Butler n Court',
#  'Ackerman John R, tailor Hoyt n Atlantic ',
#  'Ackerman Samuel, music printer and engraver 90 Fulton N  Y h 163 Front',
#  'Ackley George S, porter house York op Navy',
#  'Ackley James, carpenter 234 Hudson av',
#  'Ackley John A, 150 Nassau NYh 143 Duffield',
#  'Ackley William B, lawyer 71 Nassau NYh 143 Duffield',
#  'Acosta John, merchant 76 Broad NYh 132 Sands',
#  'Acret George, surgical instrument maker Powers n Fulton',
#  'Adair Henry, ivory black factory Little Dock h 248 Marshall',
#  'Adair James, blacksmith 246 Marshall',
#  'Adair John, Shakspeare hotel Hudson av c Marshall',
#  'Adair William, printer 177 Gold',
#  'Adams Abel, milk and butter store 199 Pearl',
#  'Adams Alexander, merchant 32 Pearl NYh 124 Smith',
#  'Adams Charles, carpenter Park n Clinton av',
#  'Adams Edward, U s N 32 Hudson av',
#  'Adams Frederick L, tailor 36 State',
#  'Adams Innes C, merchant NYh Degraw op Strong Place',
#  'Adams James, merchant 18 South N Y h Schermerhorn n',
#  'Adams John, Hamilton av n Ferry (Boerum',
#  'Adams J W, civil engineer Hoyt n State (Classon av',
#  'Adams Joseph J, dry goods store 171 Fulton h Myrtle n',
#  'Adams Philip P, shoemaker Pacific n Hoyt',
#  'Adams Russell R W, merch’t 116 WallN Y h 6 Joralemon',
#  'Adams Samuel P, sailmaker Little c United States',
#  'Adams Thomas, broker 71 Wall NYh 316 Gold',
#  'Adams Thomas, daguerreotyper Myrtle av n Classon av',
#  'Adams William T, moulder Plymouth n Jay',
#  'Adams William, laborer 1 McKenney',
#  'Adams William, laborer r 295 Prospect',
#  '*Adams Robert, waiter 43 Talman',
#  'Adderloy James, laborer 10 Vine',
#  'Addoms William, merch’t275 Broadway NYh 393 Atlantic',
#  'Addy Edward 50 Middagh (tionary 262 Fulton',
#  'ADEY AT.ONZO A, aeolian piano fortes music books and sta-',
#  'Adlum Thomas, laborer 3 York',
#  'Aeschelman George, hair dresser Flushing n Kent av',
#  'Aesop Thomas, Tillary c Canton',
#  'Afflick Davis, keeper of the penitentiary Crowhill',
#  'Agan Patrick, laborer 77 Fork',
#  'Agar Mrs Edward, 167 York',
#  'AGENCV Awn rNTELLiGENcE OFFICE, 1 Tillary c Fulton',
#  'Agnew Robert T, watch glass mafr 16 Cottage Row Furman',
#  'Ainslie Francis, importer 150 Front NYh Clermont n',
#  'Akhurst John, taxidermist 15 Prospect ',
#  'Alker J, shoemaker 95 Prospect Fulton av',
#  'Akin Isaac D, merch’t 10 Old Slip N Y, h Sackett n Clinton',
#  'Albertson Charles H, carpenter 110 Hudson av',
#  'Albertson Joseph R, blockmaker 114 Hudson av',
#  'Albertson & Simonson, builders 68 York',
#  'Albin William, 49 Middagh',
#  'Alburtis William C, shoe store NYh Front c Washington',
#  'Alcorn William, tailor 43 Main',
#  'Aldage James, ship carpenter 108 Gokl',
#  'Alderton Robert, cot maker 39 Carlton av',
#  'Aldridge E C, IS st n 4th av Gowanus',
#  'Alexander Frances, widow 80 High',
#  'Alexander Ed win, Hicks c Sackett ',
#  'Alexander George W, book-binder 7 Spruce NYh 128 Prospect',
#  'Alexander Henry Jr, Hicks c Sackett',
#  'Alexander H W, 4th ward hotel Fulton c Myrtle av',
#  'Alexander John, shade maker 4 Franklin Place',
#  'Alexander James K, book-keeper Bcdford n Myrtle av',
#  'Alexander Joseph, tailor Flushing c Franklin av',
#  'Alexander Joseph, milkman Flushing av n Spencer',
#  'Alexander Mark, milkman Spencer n Flushing av',
#  'Alexander Robert J, sergeant u SM -53 Hudson av',
#  'Alexander William, 51 Hoyt',
#  'Alexander Thomas, tavern and painter 152 Myrtle',
#  'Alexander William S, accountant Myrtle av a Steuben',
#  'so',
#  'Alford Chas, druggist labeller 43 Atlantic ',
#  'Alger Geo, grocery flour & feed store & brick yard 3d av c 27th st Gowanus',
#  'Alger George F, laborer 3d av Gowanus',
#  'Allen Abraham, mason 93 Cranberry',
#  'Allen Albert G, mer’t 351 Broadway N Yh44 Sydney place',
#  'Allen Bartlett, ship carpenter Front c Garrison',
#  'Allen David, blacksmith Water n Fulton h 106 Bridge',
#  'Allen Edward, cooper 148 High',
#  'Allen Elizabeth, widow 63 Hudson av',
#  'Allen George, cooper 29 Talman',
#  'Allen George, 179 Clinton',
#  'Allen Henry, ship master 10 Monroe place',
#  'Allen Hugh, agent N Y, h 67 Baltic',
#  'Allen Isaac, mason IS2 Jay',
#  'Allen John, laborer 3d av e Bridge road Gowanus',
#  "Allen John, merchant N Y' h 67 Baltic",
#  'Allen John, agent 157 Cedar N Y h 67 Baltic',
#  'Allen J Lewis, mason 359 Hudson av',
#  'Allen John, carman r 182 Jay',
#  'Allen John, cooper 122 Adams c High',
#  'Allen Julian L, commission merchant N Y h 8 Willow place',
#  'Allen Moses, stock broker NYh 264 Hicks',
#  'Allen N V, grocer 270 Washington c Myrtle av',
#  'Allen N, laborer r 108 Navy',
#  'Allen Peter, seaman 62 Front',
#  'Allen Robert, glass cutter Squire’s buildings n Willow',
#  'Allen Robert, porter Columbia e Warren',
#  'Allen Robert, laborer Park n Vanderbilt av',
#  'Allen Robert, blacksmith 255 John',
#  'Allen Samuel R, Plymouth n Jay ',
#  'Allen Samuel, shoemaker Myrtle n Classon av h Classon n Flushing av',
#  'Allen Sarah, nurse Columbia c Warren',
#  "Allen W'illiam, butcher 3d av c 16th st Gowanus",
#  'Allen William H, clerk Classon n Flushing av',
#  'Allen William, stone cutter 51 Tillary',
#  'Allen William H, 36 Sackett ',
#  'ALLEN & Co., LONG ISLAND GROCERY, 270 Washington e Myrtleav',
#  'Aller Amos, merchant N Y h 45 Willow',
#  'Alley Joseph B, printer Duffield n Fulton av',
#  'Allgeo & Linington, grocers Flatbush turnpike c Atlantic',
#  'Allien H V, importer S Maiden Lane NY h 182 Atlantic',
#  'Allison John, laborer Water n Bridge',
#  'Allison John P, builder Cottage place 106 Columbia',
#  "Allison W'illiam, salesman Wyckoff n Bond",
#  'Alshelsky Theodore, furrier Bergen n Powers',
#  'Althlser William, carpenter DeKalb av c Raymond',
#  'Alwick Jacob H, cook Livingston n Hoyt',
#  'Alvey Sarah, widow Smith c Bergen',
#  'Allyn Francis L, clerk 207 Front',
#  'Allyn Peter, sign painter 57 Wyckoff',
#  'Alpers Martin, grocer Fulton av c Gold',
#  'Alpin John, artist Prospect Hill',
#  'Alsgood Peter, grocer Carlton c Park av',
#  'Alvin James, carpet weaver 234 Fulton h 28 Everitt',
#  'Alway Edward, Red Hook',
#  'Al way John, Red Hook',
#  'Amberman Peter N, carpenter 380 Hudson av',
#  'Amberman Richard, carpenter 135 Nassau',
#  'Ambrose George, builder Court n Pacific',
#  'Ambrose Mrs John, Court n Pacific',
#  'Amer William, cooper 18 Talman',
#  'Amies Maria, widow 2 Debevoise',
#  'Ammerman Nicholas, groeer 40 Carlton av',
#  'Ammerman Richard, 8 Vine',
#  'Ammon Samuel, Bugbies Alley n Fulton (N Y',
#  'American Gutta Percha Co, 43 Water office 181 Broadway',
#  'AMERICAN HOTEL, 26 Fulton, John Jones Proprietor',
#  'Ames Daniel, artist Division n DeKalb av',
#  'Ames W H, 34 Joralemon',
#  'Ames Wyllys, insurance agent 21 Sackett',
#  'Ametrano Anthony, 80 York',
#  'Amy Daniel, market Court c Dean',
#  'Anderson Alexander, ship carpenter 3 Jay n Plymouth',
#  'Anderson Alexander, stonecutter 64 Pacific',
#  'Anderson Benjamin, grocer 155 Jay c Nassau',
#  'ANDERSON CHARLES F, architect 17 Park Place NY h Col-',
#  'umbia n Hamilton av',
#  'Anderson David, tailor 234 Hudson av',
#  'Anderson Dennis, hostler 15 College Place',
#  'Anderson David, mason Bond n State',
#  'Anderson D, brown and blue stone yard Water b Adams',
#  'and Washington h. 5 Monroe Place',
#  'Anderson Ellen, widow 75 Prince (road e 9th st.',
#  'Anderson Henry, merchant tailor 72 Pine NYh Gowanus',
#  'Anderson John, clerk 98 Boerum',
#  'Anderson John B, 155 Sands c Gold',
#  'Anderson John, laborer Willow c Pacific',
#  'Anderson Joshua, 155 Jay c Nassau',
#  'Anderson Lucinda, widow 180 Nassau',
#  'Anderson Mrs , 9 Prospect',
#  'Anderson Michael, tin roofer 179 Concord (Schermerhorn',
#  'Anderson P B, stone yard Columbia c Pacific h Boreum c',
#  'Anderson Rob’t G,inspector of stone U S dry dock 271 Pearl',
#  'Anderson Robert D, iron railing mfr. 82 Livingston (ston',
#  'ANDERSON- & CLAYTON, iron railing mfr. Boerum n Living-',
#  'ANDERSON & JOHNSON, brown and blue stone yard Water h',
#  'YVashington and Adams',
#  '*Anderson Barrett, porter 64 Jay',
#  '*Anderson William, laborer 64 Jay',
#  'Andree Frederick, bookkeeper 105 Washington',
#  'Andrews Charles, rug manufacturer Kent n DeKalb av.',
#  'Andrews George, oil manufacturer Kent n Flushing av',
#  'Andrews James, merchant 59 Broadway NYh Classon n',
#  'Fulton av',
#  'Andrews Joseph D, hardware dealer 33 Myrtle av',
#  'Andrews , butcher Columbia n Sackett',
#  'Andrews William, butcher 44 Baltic',
#  'Andrews William M, ice merchant 140 Furmanh 37 TVillow',
#  'Angel William, 4 Vine',
#  'Angrave Clifton, merchant 62 Pine NYh 191 Clinton',
#  'Angus Henry, constable 2nd Ward 39 Front',
#  'Angus John, shingle shaver 281 Pearl',
#  'Angus William J, silversmith Amity n Court',
#  'Annett Alexander, coal dealer 7 Water',
#  'Annett James, union coal yard Adams c York h 72 Adams',
#  'Ansell Henry, broker Hicks c Poplar',
#  'Anthony David C, merchant 24 Cedar N Y h 97 Concord',
#  'Anthony Edward, western insurance office N Y h 24 Garden',
#  'Anthony Hester, widow Red Hook',
#  'Anthony W R, 43 Wyckoff n Smith',
#  'Anlonidus Matthew, cabinet maker 146 High',
#  'Antony Fhilip, baker Cranberry c Henry (95 Myrtle av',
#  'Applegate Daniel B, Phoenix market Willoughby c Gold h',
#  'Applegate Edward, mason and oyster saloon Prince c Myrtle',
#  'Applegate George S, Franklin market 149 Myrtle av',
#  'Applegate Lewis, carpenter Myrtle av n Raymo,nd',
#  't',
#  'BROOKLYN DIRECTORY, 23',
#  'Applegate William R, butcher Myrtle ay n Raymond',
#  'Appleton Samuel B, clcrk 143 Fulton',
#  'Appleyard Thomas, painter Bergen n 4th av',
#  'Appleyard William, cabinet maker 54 Fulton',
#  'Appleyard William, carman Tillary n Navy',
#  'Arbona Francis R, blacksmith 60 Carlton n Myrtle av',
#  'Arbuckle Andrew, laborer Adams b Watcr and Front',
#  'Archer George B, merchant 38 Concord',
#  'Arcularius John, Fulton market NYh 97 W ashington',
#  'Arcuiarius Letitia, widow of P I Pacific n Powers',
#  'Arkness Anthony, painter Hamilton av n Ferry (Front',
#  'Armfield Joseph A, spice mills Hudson n Fulton av h 218',
#  'Armitage James, saw manufacturer and tavern 206 Atlantic',
#  'Arms Charles, merchant 159 Pearl N Y h 69 Orange',
#  'Armshaw Richard, plasterer 41 Main',
#  'Armstrong Benjamin, druggist N Y h 46 Sauds',
#  'Armstrong Elizabeth, Pacific n Court',
#  'ARMSTRONG S T & F W American guttapercha factory Wa-',
#  'ter b Dock and Main office 1S1 Broadway NYh',
#  'Mansion house',
#  'Armstrong James, stone cutter Red Hook',
#  'Armstrong John, tinman 15 Prince',
#  'Armstrong John, laborer Pacific n Vanderbilt av',
#  'Armstrong Patrick, laborer Bridge c Water',
#  'Armstrong Thomas, watch and clock maker 40 Hicks',
#  'ArtNoLn A F, dry goods store 137 Myrtle av c Prince',
#  'Arnold Daniel H, merchant 60 Pine N Y h 38 Pierrepont',
#  'Arnold Daniel S, mercht19 Cortlandt N Y h 73 Cranberry',
#  'Arnold Edward H, mercht 34 Beaver N Y h 65 Joralemon',
#  'Arnold George, laborer 25 Green lane',
#  'Arnold George, mercht 147 Broadway N Y h 100 Middagh',
#  'Arnold Samuel, carpenter Court n Degraw',
#  'Arnold Samuel G, clerk common council Hoyt n Atlantic',
#  'Arnold William M, undertaker Boerum n Pacific',
#  'Arrent Stephen, Union n Columbia',
#  'Arrents Edward, agent Powers n Dean (Atlantic',
#  'Arrosmith Benjamin E, merchant 145 Broad NYh Hoyt n',
#  'Arthur Edward H, 235 Hicks',
#  'Arthur George D, Washington n Fulton av',
#  'Arthur John, livery s(able keeper Fulton n City Hall h 9 Pearl',
#  'Arthur William, engineer 254 Gold n Myrtle av',
#  'Ash Ann, widow 101 Nassau',
#  'Ash Simon, brown stone cutter 101 Gold',
#  '*Ash Jane, widow 41 Hicks c Middagh',
#  'Ashby Samuel B, 15 Hicks',
#  'Ashfield James, mason Hoyt n Pacific',
#  'Ashman Mrs, nurse 83 Cranberry',
#  'Ashton Catharine, widow Cole st n Hamilton av',
#  'Ashtroth George, stage driver Kent av north',
#  'Ashworth Henry, stone cutter 28 Green lane',
#  'Ashworth John, flagger 48 Green lane',
#  'Askham John, agent 71 Nassau',
#  'Aspenall Joseph, stage driver Flushing n Classon av',
#  'Aspenall William, shoemaker Park c Franklin av h Flushing',
#  'Asfen Wm, cooper 42 Water N Y h 99 Jay ',
#  'Atfrold William, porter 50 Pacific n Classon av',
#  'Atkins Edwin, merchant 38 South N Y h 9 Monroe place',
#  'Atkins Job, plasterer Schermerhorn n Bond',
#  'Atkins Joseph, daguerreotypist 219 Fulton',
#  'Atkins Joshua, mason 10 Carll',
#  'Atkins Joshua, merchant 38 South N Y h 9 Monroe Place',
#  'Atkins Samuel H, shoemaker Boerum c Pacific',
#  'Atkins William, shoemaker 254 Atlantic',
#  'Atkinson B, carpenter Navy n De Kalb av',
#  'Atkinson James, grocer 330 Atlantic e Hoyt',
#  'Atkinson John P, merchant 105 Wall N Y h 26 Garden',
#  'Atkinson O, merchant N Y h 4 Union Place',
#  'Atkinson Robert, carman 14 Plymouth',
#  'Atkinson Rev Timothy, 65 Remsen',
#  'Atkinson William, clerk 206 Washington',
#  'ATLANTIC BANK, 55 Fulton',
#  'ATLANTIC WHITE LEAD WORKS, Marshall n Gold',
#  'ATLANTIC MARKET, Atlantic c Hicks',
#  'Atterbury William, grocer 14 Tillary',
#  'Atwater David F, physician Remsen 1 door from Clinton',
#  'Atwater George, 42 Concord',
#  'Atwater George M. merchant NYh Remsen n Clinton',
#  'Atwater James C, mei chant N Y h 41 Livingston',
#  'Atwater Leonard D, merchant N Y h 42 Concord',
#  'Atwater Robert, 42 Concord',
#  'Atwater Win C, 57 Water N Y h 26 Prospect',
#  'Atwood , bowling saloon Fulton c Furman hill Pearl',
#  'Auburn Thomas E, accountant 251 Gold',
#  'Auger John B, storage Furman h 102 Joralemon',
#  'August John, hair dresser Montague hall Court st',
#  'Augustus Charles, Crow hill Bedford',
#  'Auld J B, editor and lawyer 6 Degraw',
#  'Auld & Randall, grocers 10 Hamilton av',
#  'Austin John, carpenter 74 Water',
#  'Austin Joseph, tinsmith Washington c York',
#  'Austin Matthew, carpenter 2 Kelsey’s alley',
#  'Austin Richard S, Boerum c Atlantic',
#  'Austin S E, widow 52 Willow (182 Jay',
#  'Austin Theodore, marketman Washington market NYh',
#  'Avery John R, seaman 11 Cottage row Water',
#  'Avery R H, clerk Adelphi n Jamaica av (Smith',
#  '-—Avery Samuel P, wood engraver 129 Fulton N Y h 114',
#  'Avery Timothy D, mason 110 Tillary',
#  'Avila John, painter 134 Nassau',
#  'Avis William T, tailor 94 Duffield',
#  'Aymar Samuel, mer. 50 South N Y h 74 Pacific n Clinton',
#  'Ayres Andrew, merchant tailor 25 Myrtle',
#  'Ayres Daniel, merchant NYh 131 Columbia',
#  'AYRES DANIEL, physician and surgeon Montague place 2d',
#  'door from Court (Henry h 131 Columbia',
#  'Ayres Gabriel D, chemist and apothecary 129 Atlantic c',
#  'Ayres Robert, merchant 46 Front N Y h 28 Joralemon',
#  'B',
#  'Babad Henry, broker 43 New NYh 422 Atlantic n Powers',
#  'Babbit Charles W, ship carpenter 37 Adelphi n Myrtle av',
#  'Babbridge Benjamin, ship master 111 Pacific',
#  'Babcock Courtland(, man’r of jewelry 10 Cortlandt NYh',
#  'Bedford Corners',
#  'Babcock Robert D, Fulton market h 146 Concord',
#  'Bach John C, distiller 48 Sands',
#  'Bach, Son & Co, rectifiers and distillers Furman n Doughty',
#  'Bach Margaret, widow of Robert, 20 Concord',
#  'Bach Mary, widow,boarding house 87 Henry',
#  'Back Margaret, widow 138 Nassau (Carlton n Myrtle av',
#  'Backhouse Edward T, fruit merchant 16 Fulton NYh',
#  'Backus Evans, stoves & hardware 134 Myrtle av c Prince',
#  'Backus John, stove & hardware dealer 134 Myrtle c Prince',
#  'Backus Rev Samuel, 203 State',
#  'Backus Samuel W, carpenter 220 Navy',
#  'Bacon James, laborer Water n Jay',
#  'Bacon James, clerk 2 Butler ',
#  'Bacon J B, principal of Warren polytechnic school, 68 Warren b Clinton & Henry',
#  'Bacon Rev David W, pastor R C Ch of the Assumption 82',
#  'York n Jay ',
#  'BADEAU ISAAC, engraver 102 Nassau c Ann NYh 127 Prospect',
#  'Badcock Henry, chemist 1 Hudson av',
#  'Badger Ann, 83 Joralemon (Washington',
#  'Badger D D, iron shutter man’r 44 & 46 Duane NYh 231',
#  'Badger George S, accountant 138 Sands',
#  'Badger James M, watch maker 266 Pearl NYh 122 YVillow',
#  'Baggot Thomas, glass blower Schermerhorn n Boerum',
#  'Bagley Dominick, carpenter 7 Prince',
#  'Bagley James, carman Carll n Willoughby',
#  'Bagley Patrick, laborer Raymond n Tillary',
#  '*Bagley George, laborer 285 Hudson av',
#  'Bagnell G R, storage Union b Hicks and Columbia',
#  'Bagot Joseph, pork dealer 92 Court',
#  'Bahan Edward, laborer Navy n Bolivar',
#  'Bailey Aretus, Franklin House 15 Fulton c Water',
#  'Bailey E & J A, house agents 95 Pearl',
#  'Bailey Elisha, 11 Lawrence',
#  'Bailey Elizabeth, widow Water c Hudson av',
#  'Bailey George, miller r 153 Hudson av',
#  'Bailey H F, engineer Classon n Flushing av (280 Jay',
#  'Bailey James, lace and hosiery store 157 Fulton n High h',
#  'Bailey John D, 111 Nassau',
#  'Bailey John H, laborer 202 Prospect',
#  'Bailey John Townsend, accountant 111 Nassau',
#  'Bailey Joseph P, furrier 154 Santis',
#  'Bailey Robert, coal dealer 47 Cranberry',
#  'Bailey Thomas, Clove road n railroad Bedford ',
#  'BAILEY WILLIAM, Apothecaries Hall 206 Fulton c Pineapple h 22 Sands',
#  'Bailey William B, ship carpenter 147 High',
#  'Bailey William, lace and hosiery store 157 Fulton h 157 Jay',
#  'Bailey William, 59 High (Water',
#  'Bailey & Baldwin, proprietors Franklin House 15 Fulton c',
#  '*Bailey Benjamin, waiter Hart’s alley n Gold',
#  'Bainbridge John, saddler 284 Atlantic',
#  'Bainbridge Richard, stationer 47 Cliff N Y h 105 Clinton',
#  'Baird Robert, mason 9 Jay',
#  'Baird Wil)iam, contractor Wyckoff n Smith',
#  'Baisley John, furnishing undertaker & sexton 1st Dutch Ch',
#  'Baisley Lewis, carpenter Livingston n Nevins ',
#  'Baisley Nehemiah, carpenter Nevins n Schermerhorn 309 Fulton',
#  'Baisley Peter, carpenter Dean n Powers',
#  'Baisley Samuel, gardener Spencer n Flushing av',
#  'Baisley Thomas, mason 118 Willoughby',
#  'Baker A, 244 Pearl',
#  'Baker Augustus D, merchant 5 South NYh 103 Clinton',
#  'Baker Caleb W, 47 Butler',
#  'Baker Charles H, agent Furman n Joralemon',
#  'Baker Chas S, grocer 6 Linden row Fulton h 20 Willoughby',
#  'Baker Daniel, physician 26 Myrtle av',
#  'Baker Edward, architect 222 Henry',
#  'Baker Edwin, carpenter 225 Atlantic h 8 Garden',
#  'Baker Elisha B, pilot 73 Pineapple',
#  'Baker Erasmus D, U s N Navy n Myrtle av',
#  'Baker E E, stove dealer 111 Beekman NYh 244 Pearl',
#  'Baker Henry, clerk 9 Degraw',
#  'Baker George E, blacksmith Pacific n Court h Baltic n Smith',
#  'Baker Hiram, cooper 51 Tillary',
#  'Baker Isaac D, publisher 145 Nassau N Y h 13 Schermerhorn',
#  'Baker James A, mason 111 Willoughby',
#  'Baker James, tailor 15th st n Sth av Gowanus',
#  'Baker Jane, 189 York ',
#  'Baker Jesse M & Co, grocers 6 Linden row Fulton h 20 Willoughby c Pearl',
#  'Baker John, Van Brunt st Red Hook',
#  'Baker John, shoe store 159 Myrtle h Cumberland n Myrtle',
#  'Baker J G, 66 Adelphi n Myrtle av',
#  'Baker John H, merchant 178 Washington c Concord',
#  'Baker J O, ship master 145 Hicks',
#  'Baker Lewis, carpenter 3 Kelsey’s alley',
#  'Baker Lewis, laborer 3 Kelsey’s alley',
#  'Baker Mary, widow 110 Fulton',
#  'Baker Richard G, shoe dealer 159 Myrtle av',
#  'Baker Smith, grocer NY h 22 Henry',
#  'Baker Stephen, Kent n Flushing av',
#  'Baker Sylvanus, hotel junc. Flatbush turnpike & Atlantic av',
#  'Baker Thomas, laborer 11 State',
#  'Baker William H, machinist Kent av North',
#  'Baker William E, clerk 10 Cottage row Furman',
#  'Baker Wil)iam, Cole st Red Hook',
#  'Baker William, mer. 165 Maiden Lane Y N hill Sands',
#  'Balance Joseph, carpenter 193 Myrtle av',
#  'Balch E, widow, boarding house 1 Atlantic',
#  'Balchen George, mer. 105 Wall N Y h Fleet n Fulton av',
#  'Baldwin Bedell, mason Myrtle av c Steuben',
#  'Baldwin Benjamin, grocer 148 High',
#  'Baldwin & Burtis, grocers Bridge c High',
#  'Baldwin Caleb H, mason 345 Gold',
#  'Baldwin C P, merchant 8 Cedar NY h 35 Sydney place',
#  'Baldwin Charles, pump and block maker 187 Gold',
#  'Baldwin David M, cooper 117 Concord',
#  "Baldwin David W, cooper 71 C'oncord",
#  'Baldwin Ezekiel, Franklin House 15 Fulton',
#  'Baldwin Ezra, grocer Bridge c High h 162 Bridge',
#  'Baldwin Garret, mason 114 Willoughby',
#  'Baldwin James H, cooper 117 Concord',
#  'Baldwin Jane, widow of George, 241 Hudson av',
#  'Baldwin John, carpenter 86 Adams',
#  'Baldwin Joseph, blacksmith Flushing av op Spencer',
#  'Baldwin Lewis N, grocery and feed store Myrtle av c Gold',
#  'Baldwin Miss Maria, milliner 111 Fulton',
#  'Baldwin Moses, marketman 46 Front',
#  'Baldwin M, carpenter Cumberland n Park av',
#  'Baldwin Nelson, ship carpenter 240 Hudson av',
#  'Baldwin Phineas & Co,grocers Myrtle av c Adams',
#  'Baldwin Platt, blacksmith Baltic c Smith',
#  'Baldwin Roswell B, seaman 299 Adams',
#  'Baldwin Platt, milkman Putnam c Bedford av',
#  'Baldwin Samuel, 238 Hudson av',
#  'Baldwin Sarah, dressmaker Schermerhorn n Nevins',
#  'Baldwin & Davis, man’rs of stationery Myrtle av c Graham',
#  'Baldwin Turner, laborer 27 Green lane n Prospect',
#  'Baldwin William, commission merchant 65 Johnson',
#  'Balen J D, 52 Pierrepont',
#  'Balen Peter, fruit merchant 186 Front N Y h 52 Pierrepont',
#  'Balfe John R, clerk 56 Baltic n Smith',
#  'Balfe Patrick, baker Columbia c Pacific',
#  'Balieff Robert, merchant N Y h 163 Washington',
#  'Ball Andrew, milkman Bedford n DeKalb av',
#  'Ball Edward, draper and tailor 55.5 Atlantic ',
#  'BALL GEORGE C, M D, coroner, office Montague p)ace n Court',
#  'Ball John, physician and surgeon 195 Washington h 36',
#  'Bali Joseph, Wyckoff n Court (Concord',
#  'Ball Randolph D, ship carpenter 67 Sands',
#  'Ball Reuben, carpenter F)atbush turnpike c Nevins',
#  'Ball Thomas W, ivory turner 79 Poplar',
#  'Bail William, shoemakor 214 Raymond',
#  'Ballans William, laborer Water n Bridge',
#  'Ballantine James, ferryman 82 Tillary',
#  'Ballantine William, 82 Tillary',
#  'Ballard Rev J, publisher N Y Recorder, 240 Pearl c Johnson',
#  'Ballard L, furrier 128 Water N Y h 98 Clinton',
#  'Ballecke Mary, Court n Pacific',
#  'Balmano Robert, accountant 4 Dcgraw n Court',
#  'Balser Mary, widow 91 Hudson av',
#  'Balsey Joseph, 13 Degraw place i',
#  'Balsor John, pilot 74 Washington',
#  'Balston Samuel, 8 Union',
#  'Baltzer William, 4 Cottage row Columbia n Joralemon',
#  'Bamber John, stevedore 196 Front',
#  'Bamber Richard, boarding house 27th st n 3d av Gowanus',
#  'Banker Abraham, reporter 102 Concord',
#  'Bancroft George P, lumber dealer and measurer 6 Boerum',
#  'Bancroft Horace, hatter Flushing n Kent av',
#  'Banhart Christian, laborer Flushing n Franklin av',
#  'BANK SAVINGS, at the cor Fulton and Concord',
#  'Banks George, laborer Union n Van Brunt',
#  'Banks Ma.y, widow 270 Hicks n State',
#  '*Banks Peter, laborer 266 Marshall',
#  'Bannen Bridget, widow Raymond n Myrtle av',
#  'Bannen Thomas, contractor Dikeman st Red Hook',
#  'Bannon Daniel, mason 130 Tillary',
#  'Bannon John, marble polisher 188 Pearl',
#  'Bannon Michael, laborer Raymond n DeKalb av',
#  'Banta David, cap maker 65 Middagh',
#  'Banta John P, clerk Red Hook Place n Fnlton av',
#  '*Banyan Benjamin, laborer Pacific n Court',
#  'Baptist Edward, pencil maker 186 Water n Hudson av',
#  'Barber George, engineer r 29 Front',
#  'Barber John, engineer 30 Hicks',
#  'Barber Joseph, speculator Cumberland n Myrtle av',
#  'Barber Mrs   , corset maker MyTtle av n Raymond',
#  'Barber Robert, bookbinder 186 Water n Hudson av',
#  'Barber Samuel, merchant 79 Water NYh 194 Atlantic',
#  'Barber Willard, barkeeper 84 Fulton',
#  'BARBER WILLIAM S, bookbinder 22 High',
#  'Bard Brothers, 102 Front c Pearl office 101 William N Y',
#  'Bard Edmund H, goldpen manufacturer 101 William N Y',
#  'factory Pearl c Front h 138 Fulton',
#  'Bard George J, gold pen maker 145 Sands',
#  'Bard James D, gold pen maker 101 William N Y h 47 Sands',
#  'Bardwell Robert, lamp store 37 Huson av',
#  'Bare David, superintendent Brooklyn City Hospital Hudson',
#  'av b Layfayette and Fulton av',
#  'Barker David S, merchant 22 Pine N Y h 32 Willoughby',
#  'Barker Jacob, milkman Clove rd Bedford',
#  'Barker John, painter 228 Hudson av',
#  'Barker John, tailor 215 Fulton c Sprague Place',
#  'Barker Josiah H, Van Brunt st Red Hook',
#  'Barker Owen, rag dealer 4 Howard Place Water c Main',
#  'Barker Richard, accountant 110 Degraw',
#  'Barker Sarah J, widow, boarding house 233 Fulton',
#  'Barker Stephen W, shoemaker 89 Main',
#  'Barker Sylvester, carpenter 206 Bridge',
#  'Barker William, produce dealer N Y h 245 Bridge',
#  'Barkman F J W, shipmaster 73 Nassau',
#  'Barkuloo Abraham, clerk 257 Gold',
#  'Barkuloo Elizabeth, widow of YVynant, 225 Bridge',
#  'Barkuloo Henry, carman Shermerhoin n Power.s',
#  'Barkuloo Maria, widow 213 Washington',
#  'Barkuloo Tunis, 3d avenue Gowanus',
#  'Barlow Michael, sawyer 201 High',
#  'Barlow William If, clerk 14 Douglas',
#  'Bannon Michael, shoemaker Bridge c Tillary',
#  'Barnard Charles T, exchange broker NYh 170 Henry',
#  'Barnard D P, lawyer N Y h 66 Court (Bond',
#  'Barnard J W, jobber 93 William NYh Schermerhorn n',
#  'Barnard Mary, widow 129 Duffield n Willoughby',
#  'Barnes Alfred S, accountant N Y h 22 Garden',
#  'Barnes C, sailmaker Schermerhorn b Hoyt and Smith',
#  'Barnes Charles L, hardware dealer 99 Maiden Lane NYh',
#  '100 Willoughby',
#  'Barnes Charles T, watchmaker 133 Nassau',
#  'Barnes Chauncey, joiner 15 High',
#  'Barnes David A, stevedore 98 Smith n Warren',
#  'Barnes Henry, painter 16 Myrtle av',
#  'Barnes Henry W, merchant N Y h 113 Henry',
#  'Barnes James, tin stamper 69 Pearl',
#  'Barnes Joseph, tinsmith Spencer n Willoughby ',
#  'Barnes Samuel C, teacher & com. of deeds Classon n Fiush- ing av',
#  'Barnes William, cage maker Franklin n Myrtle av',
#  'Barnes William M, painter Navy c Delialb av',
#  'Barnett Alexander, furniture store 80 Fulton',
#  'Barnett Henry, brushmaker 19 State',
#  'Barnett F, morrocco case mfr Court b Atlantic and Pacific',
#  'Barnett John, stereotyper 88 Middagh',
#  'Barney Hiram, lawyer 29 Wall N Y h 70 Pierrepont',
#  'Barney James B, builder 115 Myrtle av',
#  'Barney John, mason Warren n Smith',
#  'Barney Penelope, widow 41 Stanton',
#  'Barnier J. J. merchant 83 JohnN Y h 3 YVillow',
#  'Barnsdall John, cutter 80 Cherry N Y h 56 Adams',
#  "Barnum Charles, clothier 252 Pearl N Y' h 17 Myrtle av",
#  'Barr Alexander M, 139 Fultonh 145 Jay',
#  'Barr , teacher 147 Hicks',
#  'Barr John, Pacific n Powers',
#  'Barr John, baker 85 Cranberry',
#  'Barr John, laborer 1 Hall’s buildings Furman',
#  'Barr Michael, confectionary and fruit 166 Myrtle av',
#  'Barre Tobias, coachmaker 22 Henry',
#  'Barre Walter, coal dealer Pearl c Plymouth h 22 Henry',
#  'Barrell E L, ferry master 88 Sackett',
#  'Barrell George, shipmaster 234 Bridge',
#  'Barret Alfred, 47 Front N Yh 60 Harrison',
#  'Barrett Andrew, laborer Navy n Park av',
#  'Barrett George, painter 72 Atlantic',
#  'Barrett John B, locksmith 184 York',
#  'Barrctt Lewis A, porter DeKalb av n Bolivar',
#  'Barrett Peter M, carpenter 75 Pacific n Boerum',
#  'Barrett Samuel H, biscuit dealer 98 Gold',
#  'Barrett William, tailor 6 Kelsey’s alley',
#  'Barrett William, ship joiner Myrtle av n Cumberland',
#  'Barrick Nathan, glazier 150 Concord',
#  'Barrin Joseph, grocer Columbia c Amity',
#  'Barron James, laborer 221 Hudson av',
#  'Barrows Ebenezer, ranges 228 Water NYh 196 Pearl',
#  'Barrowsky Charles E, painter Navy n Myrtle av',
#  'Barry Arthur, laborer 2 Elizabeth',
#  'Barry Dennis, laborer 62 Front',
#  'Barry James, marble cutter Boerum n Dean',
#  'Barry YVilliam H, painter 28 Boerum',
#  'Barstow Caleb, merchant 98 Pine N Y h 20 Sands',
#  'Barstow Henry W, merchant 98 Pine N Y h 18 Sands',
#  'Barter Joseph, mason Dean n Boerum',
#  'Barth Richard L, cigarmaker 33 Hudson av',
#  'Bartley Peter, laborer 13 State',
#  'Bartlett Gamaliel, grocer 4 Front N Y h 21 Joralemon',
#  'Barter John, mason 74 Harrison',
#  'Barton Daniel, Court n Degraw',
#  'Barton John B, carpenter 25 Adelphi',
#  'Barton Robert, blacksmith 233 Hudson av',
#  'Barton William, carpenter 47 Butler (Columbia',
#  "Barton W'illiam, merchant 18 Cliff N Yh9 Colonade row",
#  'Barton William, printer 177 Nassau',
#  'Bartow Benjamin P, carman 165 Hudson av (ingtoa',
#  'Bartow Edgar J, paper merchant 77 John NYh 160 W’ash-',
#  'Bartow William E, carpenter 71 Concord',
#  'Bartow YVilliam, fruit dealer 129 Bridgc',
#  'Basiorth Enos, carpenter 36 Prince',
#  'Bass Marcus, cap store 59 Atlantic',
#  'Bassett Francis M, druggist 158 Atlantic',
#  'Bassett Isaac H, merchant N Y h 75 Remsen n Henry',
#  'Bassett John, locksmith 35 Hudson av',
#  'Bassett L D, merchant 25 South NYh Dean n Nevins',
#  'Bassett Susannah, widow Vanderbilt av n Dean',
#  'Baston Richard, carpenter 273 Pearl',
#  'Batcheler B A, lamp store NYh 130 Myrtle av (rvanus',
#  'Batcheler Washington A, grocer 3d avb 15th and 16th stGo-',
#  'Batcheler AY’, 44 Douglass n Smith',
#  'Batcheler & Vail, grocers 19th st c 3d av Gowanus',
#  'Bate Lawrence, Red Hook',
#  'Bate Thomas, merchant 103 Maiden Lane N Y h 76 Adams',
#  'Bate Thomas Henry, merchant 103 Maiden Lane NYh',
#  'Adelphi n DeKalb av',
#  'Bates Andrew, mason Pacific n Smith (Park av',
#  'Bates Augustus, coal yard Flushing c Kent av h Franklin n',
#  'Bates & Berry, coal yard h lushing c Kent av',
#  'Bates Henry, merchant N Y h 50 State',
#  'Bates James, stone cutter 277 Atlantic',
#  'Bates John, Red Hook',
#  'Bates John, laborer 37 Hudson av',
#  'Bates Mrs, widow of William, Washington avn Fulton av',
#  'Bates YVilliam, printer Fulton c Myrtle av',
#  'Bates William, distiller Oxford st n Jamaica rd',
#  'Bath Francis, soap maker Crow Hill Bedford',
#  'BATHS, for ladies and gentlemen Columbia c Pineapple John',
#  'Bath Lydia M, widow 71 Hudson av ',
#  'Bath Raymond, rope maker Crow hill Bedford Hudson proprietor',
#  'Batterson Smith, upholsterer 154 Atlantic',
#  'Battle Mary, widow 183 Prospect',
#  'Battleson George, cabinet maker 94 Mrytle av',
#  'Batts William, U s N 58 Adelphi',
#  'Batty John W, leather dealer NYh Pacific n Smith',
#  'Bauchman Thomas, house and sign painter 93 Myrtle av',
#  'Baudouine Mrs C L, millinery and fancy store 169 .Fulton',
#  'Baulsir Conrad, ferryman 11 Carlton av',
#  'Bavel Charles, shoemaker 25 Sackett',
#  'Baxter Alvan, shipmaster 20 Tillary',
#  'Baxter A S, grocer 68 Water NYh Clinton n Degraw',
#  'Baxter Charles C, cap mfr c Cedar and Pearl NYh Sher-',
#  'inerhorn n Bond',
#  'Baxter Charles H, mercht 1-13 Maiden Lane N Y h 42 Court',
#  'Baxter John, saddle and harness maker 118 High',
#  'Baxter John, carpenter 29 Charles n York',
#  'Baxter John, laborer II Prospect',
#  'Baxter John, carman Columbiab State and Joralemon',
#  'Baxter Thomas B, oil merchant NYh Court.n Sackett',
#  'Baxter Timothy & Sons, whiting factory Water c Pearl h',
#  'Clinton n Fulton av',
#  'Baxter Lawrence, storage of Peruvian Guano 164 Furman',
#  'Bayard Thomas, ferryman 48 Bergen n Smith',
#  '*Bayard Margaret, widow 18 Ilartt’s Alley (low Place',
#  'Bayaud John, merchant 37 South William N Y h 35 Wil-',
#  'Bayer Edward, 280 Bridge n Myrtle av',
#  'Bayley John, contractor 95 Carll (108 Livingston',
#  'Baylis Abraham B, broker 30 Merchants Exchange NYh',
#  'Baylis Catharine, boarding house 193 Pearl',
#  'Baylis David B, hardware merchant 134 Atlantic',
#  'Baylis Daniel, spar maker 131 Hudson av',
#  'Baylis Gilbert C, huxter Washington market N Y h 101 Jay',
#  'Baylis Thos, builder 83 Washington h Joralemon n Henry',
#  'Baylis Thomas, gardener Clove road Bedford',
#  'Beach Alfred E, editor N Y Sun 73 Columbia',
#  'Beach Charles, pencil case maker Johnson c Fulton',
#  'Beach Evan, merchant 73 William N Y h 43 Cranberry',
#  'Beach Harvey, merchant 15 Cortlandt N Y h 59 Hoyt',
#  'Beach Joseph, 73 Columbia',
#  'Beach Lewis, grocer 23 Myrtle av c Pearl h 34',
#  'Beach William, merchant NYh 266 Jay',
#  'Beach William, 45 High',
#  'Beal John C, clerk 124 Nassau',
#  'Beal John, merchant 22 Degraw n Smith',
#  'Beals & Frazer, granite yard 3d av c 24th st Gowanus',
#  'Bealey George, frame maker 152 Hudson av',
#  'Beam Abraham U, cooper Dean n Smith',
#  'Beam George, tripe cuter Flushing av n Navy Yard',
#  'Beam Henry, baker Myrtle c Nostrand av',
#  'Boam John, cooper 130 Broad N Y h 101 State',
#  'Beam Louisa, widow 99 State',
#  "Beam Peter M, 17G York c G'reen lane",
#  'Beams B J, attorney 8 Tillary',
#  'Bean Hugh, laborer 22d st n 3d av Gowanus',
#  'Beaney Peter, gardener Pacific n Oxford',
#  'Bear David, steward city hospital Hudson av n Lafayette',
#  'Beard Job, shoemaker 310 Atlantic',
#  'Beard John, Butler n Smith',
#  'Beard John P, boot and shoe store NYh 321 Henry',
#  'Beard William, contractor 34 Wyckoff',
#  'Beare William H, clerk 15 Stone NYh Hoyt n Statc',
#  'Beasley Edward, machinist 168 Pearl',
#  'Beattie A, feed store 3-16 Fulton op Adams',
#  'Beatty Alexander, stone cutter 41 Gold',
#  'Beatty Alexander, cartman 108 High',
#  'Beatty Catharine, 56 Montague place',
#  'Beatty John, cooper Jay c Front',
#  'Beatty John, 10S High',
#  'Beatty Mark, printer Sands n Navy',
#  'Beatty Robert Jr, bookbinder 80 Wall N Y h 107 Concord',
#  'Beatty Samuel, shoemaker 40 Prince',
#  'Beatty William, segar maker 94 Sands',
#  'Beaty Andrew, painter Front n Jay',
#  'Beaty John, groccr Front c Jay',
#  'Beaumon Benjamin, grocer 21st st n 4th av Gowanus',
#  'Beaumont E B, merch’t tailor 203 Broadway NYh Clinton',
#  'n Harrison',
#  'Beaumont James, pedlar Hamilton st Red Hook',
#  'Beaumont Victor, engineer 296 Atlantic',
#  'Becar Noel J, importer Henry c Warren',
#  'Bechtel J D, merchant 90 Front N Y h 113 Livingston',
#  'Beckett Henry, locksmith 100 Orange',
#  'Bedell Cadwallader A, accountant 98 Duffield',
#  'Bedell Daniel, agent for the hire of real estate 69 Cranberry',
#  'Bedell Daniel, tanner 21 Carlton av',
#  'Bedell Mrs E, widow Classon n Flushing av',
#  'Bedell Henry, carman Classon n Myrtle av',
#  'Bedell Isaac, Myrtle n Classon av',
#  'Bedell Jacob M, clerk 118 Gold',
#  'Bedell John J, morocco dresser 73 Prospect',
#  'Bedell Moses, carman 265 Hudson av',
#  'Bedell Mott, merchant 104 Wall N Y h 33 Cranberry',
#  'Bedell Richard, blacksmith Bridge c Sands',
#  'Bedell Robert, Livingston n Hoyt',
#  'Bedell Samuel B, carriage-smith 25S Hudson av',
#  'Bedell Sarah, 180 York',
#  'Bedell Stephen H, britannia metal man’r217 Adams',
#  'Bedell Stephen, carpenter 43 Adelphi',
#  'Bedell Valentine, shipsmith 57 York',
#  'Bedford Edward, carver Hudson c DeKalb av',
#  'Bedford John G, cabinet maker Dean n Powers',
#  'Beebe Eliza, widow Flushing av n Franklin av',
#  'Beebe James, Flushing av c Graham',
#  'Beebe O A, clerk 227 Atlantic',
#  'Beebe Richard, ropemaker Kentn Flushing av',
#  'Beabe Silas R, merchant 137 Front N Y h 116 Johnson',
#  'Beebe Stanton, 98 Henry',
#  'Beebe Theophilus, pilot 36 Tillary',
#  'Beebe W J, tea merchant 137 Front N Y h 307 Bridge',
#  'Beebe William H, hatter 156 Broadway N Y h Clinton av',
#  'c Myrtle av (Powers',
#  'Beecher C E, artificial flowers 58 John N Y h Atlantic n',
#  'Beecher Rev Henry Ward, pastor Plymouth Ch h 197 AYash-',
#  'Beecher William A, Mansion House 121 Hicks ',
#  'Beekman A J, merchant 61 Liberty N Y h 73 Livingston ington',
#  '*Beekman Andrew, whitewashcr r 56 Stanton',
#  'BEERS EDWJN, exchange office 43 Fulton h 72 Sands',
#  'Beers Henry A, tailor Gold c Fulton av',
#  'Beers James B, gold pen maker 26 John N Y h 102 Nassau',
#  'Beers John H, grocer 158 Prospect',
#  'Beers Lewis, musician 65 Poplar',
#  'BEERS NATHAN T, stove man’r 45 Fulton h 103 YVilloughby',
#  'BEERS S A, city surveyor and engineer Montague place c',
#  'Court h 305 Gold',
#  'Beers William, spile driver Park n Vanderbilt av',
#  'Beeth Christopher, Kent n Flushing av',
#  'Behm John, grocer Johnson c Adams',
#  'Behr Henry,city weigher 33 Cottage row Furman',
#  'Beine Benjamin, glass cutter 52 State',
#  'Beine William, shoemaker Willow place c State',
#  "Belcher W'm, rule manufacturer N Y h Clinton n Myrtle av",
#  'Belfe John R, porter 56 Baltic',
#  'Belford Matthew, coachman 103 Atlantic',
#  'BEKKNAI’ ROFUS R, optician NYh 108 Hudson av',
#  'Bell Charles H, commander U s N Flushing av n Navy',
#  'Bell Jacob, seaman 16 Myrtle av',
#  'Bell James, 209 Henry',
#  'Bell James A H, paint mill Hicks n Luqueer',
#  'Bell John A, carpenter Van Brunt n Dikeman Red Hook',
#  'Bell John, clerk NYh 125 High',
#  'Bell Joseph, lime dealer foot of Amity h 35 Douglass',
#  'Bell Joseph, rigger 219 Front',
#  'Bell Robert C, land and insurance agent 3d av c 27th st',
#  'Gowanus h Williamsburgh',
#  'Bell Samuel, beer agent 90 Front c Main',
#  'Bell Thomas, bookeeper 58 Fulton',
#  'Bell William, carpenter Atlantic c Bond',
#  'Bell William, carman Plymouth n Pearl',
#  'Bellamy Joseph, brushmaker 357 Pearl NYh 57 Johnson',
#  'Bellamy William, locksmith 217 Pearl',
#  'BELLINGHAM JOHN, druggist Gold c Prospect',
#  'Beman Spencer, composition roofer 63 Atlantic h 61 Court',
#  'Beman Warren, composition roofer 63 Atlantic h Hicks b',
#  'Sackett and Union',
#  'Beman William, tanner 35 Navy n Park av',
#  'Beman & Brother, composition roofers 63 Atlantic',
#  'Bender Jacob, butcher and beer shop 56 Atlantic',
#  'Bendon Jacob, 6 Kelsey’s alley',
#  'Benedict Lewis S, shoe dealer N Y h 7 Middagh',
#  'Benedict Robert D, 279 Gold',
#  'Benedict Nathan, Kent av north',
#  'Benedict R S, 3 Middagh',
#  'Benjamin Alfred, printer YVyckoff nBond',
#  'Benjamin Henry, boot maker 1SS Water n Hudson av',
#  'Benjamin H L, physician IOS Clinton c State',
#  'Benjamin John H, grocer 155 Nassau',
#  'Benjamin William H, 20 Douglass (rison',
#  'Benjamin Wrn, mercht 31 Broad N Y h Cheeverpln Harri-',
#  'Benedict William C, physician 195 Atlantic',
#  'Bennem John, 149 Prospect',
#  'Bennett A. M, furnishing store 102 Fulton',
#  'Bennett Amy, widow, boarding house Mercein o James',
#  'Bennett Benjamin, blacksmith Furman n State h Carlton n',
#  'Park av',
#  'Bennett Benjamin, accountant 222 Pearl N Y h 144 Jay',
#  'Bennett Charles, farmer 3d av c 29th st Gowanus',
#  'Dennett Christopher, city marshal Concord c Gold',
#  'Bennett Cornelius, farmer 3d av n 27th st Gowanus',
#  'Bennett Elijah, sash and blind maker Hudson n Fulton av',
#  'Bennett George, ship joiner 47 Green Lane',
#  'Bennett George I, physician 195 Washington h 182 Adams',
#  'Bennett George L, office 102 Front h S3 Henry',
#  'Bennett Harmanus, 16 st n 3d av Gowanus',
#  'Bennett Henry, merchant Sl Water N Y h State n Bond',
#  'BENKETT JAMES, butcher Smith c Douglass',
#  'Bennett James, milkman Pacific op Washington av',
#  'Bennett James, farmer Gowanus rd',
#  'Bennett John, painter 42 Main',
#  'Bennett John Gr, carpenter Raymond n Myrtle av',
#  'Bennett John, accountant 126 Prospect',
#  'Bennett J, clerk Navy c De Kalb av',
#  'Bennett Joseph P, upholsterer and paper hanger 312 Atlantic',
#  'Bennett J B, physician 13 Cottage row Columbia n Degraw',
#  'Bennett Margaret L, widow 40 Front c Garrison',
#  'Bennett Nicholas, sexton 100 Gold',
#  'BENNETT NOSTRAND, periodical store 61 Atlantic',
#  'Bennett Peter L, 3d av Gowanus',
#  'Bennett Robert, tavern Hamilton av n Atlantic Dock',
#  'Bennett Sarah, widow of Wynaut P, 95 Fulton',
#  'Bennett Samuel M, cooper 166 Prospect',
#  'Bennett Samuel, Clove rd Bedford',
#  'Bennett Thomas, fisherman Red Hook point',
#  'Bennett William, bookeeper N Y h 147 Hicks',
#  'Bennett William S, 160 Atlantic',
#  'Bennett William H, carpenter 142 Carll',
#  'Bennett William, carpenter Classon n Myrtle av',
#  'Bennett William, milkman 5th av n Atlantic',
#  "Bennett W'illiam, carpenter 130 Myrtle av",
#  'Bennett Wm & L J, tavern Jamaica rd n Atlantic st',
#  'Bennett Wi)liam B, carpenter 18 Lawrence',
#  'Bennett & Ba)l, physicians end surgeons 195 Washington',
#  'Bennett W J & J H, shoe store 95 Fulton',
#  "Benning John, painter Smith c Wykoff'",
#  'Benning Thomas, painter 141 Atlantic h 108 Pineapple',
#  'Betion Dominick, stone cutter Court n Pacific',
#  'Benning U, laborer Red Hook (and Hicks',
#  'Benson Alfred G, merchantN Yh Montague place b Henry',
#  'Benson Charles 52 State (Water h 37 Front',
#  'Benson John, coppersmith and brass founder 56 and 58',
#  'Benson John, laborer Water n Dock',
#  'Benson Mary, widow, boarding house 75 Water',
#  'Benson YVilliam, currier 90 Smith',
#  'Benson William, grocer Columbia c Summit',
#  'Benson Wm J, coppersmith 11 Water h 85 Prospect',
#  "Benstead W''illiam M, carman 90 Navy",
#  'Benton John, Fulton shades 311 Fulton',
#  'Benton R, florist Henry c Hamilton av',
#  'Benton Walter, 91 Concord',
#  'Benzei Alexander, stone cutter 84 Hudson av (Court',
#  'Berdell Robert H, merchant 32 Front NYh Harrison n',
#  'HSergen Alexander, First Place e Court',
#  'Bergen Cornelius, First Place c Court',
#  'Bergen Cornelius B, Baltic n Henry',
#  'Bsrgen De Hart, 3rd av Gowanus',
#  'Bergen Elias H, clerk NYh 150 Joralemon',
#  'Bergen Garritt G, 3d av Gowanus',
#  'Bergen George W, grocer 26 Fulton h 15 Poplar',
#  'Bergen Henry, riding dress maker 84 Tillary',
#  'Bergen James, insurance broker 37 Chauncy Court W’all N',
#  'Y h 32 Cottage row Columbia n Union',
#  'Bergen John, fireman 120 Prince',
#  'Bergen John jr, 3d av Gowanus',
#  'Bergen John G, 3d av Gowanus',
#  'Bergen John S, 3d av Gowanus',
#  'BERGEN JOHN V, alderman 8th Ward 3d av Gowanus',
#  'Bergen Lefferts, 3d av Gowanus',
#  "Bergen Margaret, 63 'Willoughby",
#  'Bergen Michael 3d av Gowanus',
#  'Bergen Peter J, 15 Poplar',
#  'Bergen Peter comptroller 25 Hicks c Poplar',
#  'Bergen Peter G, maf. embossed paper 3davn 18th, Gowanus',
#  'Bergen Theodore 3d av Gowanus',
#  'Berger Mrs Christoper A, hermitage hotel Prospect Hill',
#  'Berkstein Augustus, jeweller 160 William N Y h 56 Adams',
#  'Bernard A, 161 Bridge',
#  'Berry Adam, tailor Washington av c Fulton av',
#  'Berry Alexander D, coal yard Flushing e Kent av h Frank-',
#  'lin b Park and Myrtle av',
#  'Berry Charles C, shipmaster Lawrence n Fulton av',
#  'Berry Edward, butcher Columbia n Amity',
#  'Berry George, packer Dean n Powers',
#  'Berry James, tailor Tillary c Prince',
#  'Berry John, lighterman 6S Bridge',
#  'Berry John, farmer Gowanus lane c 15th st',
#  'Berry John, tailor 51 Main',
#  'Berry Johnson, tailor Tillary c Prince',
#  'Berry Lewis W, painter Carlton e Myrtle av',
#  'Berry Lavinia, widow 82 Myrtle av (Jay c High',
#  'Berry Martin R, sash maker 1 St. Johns Lane NYh 137',
#  'Berry Peter J, house mover 135 High',
#  'Bemy Rachael, S3 Henry',
#  'Berry Richard, 5th av n 12th st Gowanus',
#  'Berry Richard D, ship carpenter 136 High',
#  'Berry Sarah M, widow Adelphi n Myrtle av',
#  'Berry Thomas, laborer Warren c Nevin',
#  'Berry Thomas, sailmaker Park c Vanderbilt av',
#  'Berry William, superint of Sparkman & Kelsey’s oil cloth',
#  'factory Fulton av n Washington av',
#  'Berry William, blacksmith Myrtle av c Sanford',
#  'Berry William C, shipmaster Lawrence n Fulton av',
#  'Bertine Samuel E, shoe store 123 Atlantic h 1 Atlantic',
#  'Bertine & Whitehouse, shoe store 123 Atlantic',
#  'Bertram William R, shipmaster 85 Livingston',
#  'Bertrand Adolson, tailor 156 Bridge',
#  'Bertrand Mrs Charles A, 12F Willoughby',
#  'Bertrand F G, 43 Pierrepont',
#  'Bertrand Joseph P, packer Columbia b Atlantic and Stath',
#  'Besher John, wire maker 58 Doughty',
#  'Besher Maria, widow 331 Gold',
#  'Besling Henry H, ship master 29 Cottage row Furman',
#  'Besseveer John C, laborer 113 Navy',
#  'Bessey Hiram, printer 125 Hudson av',
#  'Best Richard, merchant 274 Pearl N Y7 h 89 Pineapple',
#  'Betelle Robert, tailor 51 Main',
#  'Betham Thomas, cabinet maker 34 Hicks',
#  'BETHEL, 39 Main n Water',
#  'Betteison William, mason 17 Atlantic',
#  'Bettman James, mason 2S6 Hicks n Pacific',
#  'Betts Benjamin F, steamboat captain 57 Nassau',
#  'Betts Burril, steamboat captain 81 High',
#  'Betts Charles C, Jamaica rd Bedford',
#  'Betts Charles H, shipsmith 107 Bridge',
#  'Betts George AV, shipmaster 102 York',
#  'Betts James, paint factory Hed Hook',
#  'Betts Jane E, widow Boerum n Atlantic',
#  'Betts Maria E, school 14 Strong Place n Harrison',
#  'Betts Matthew J, ship carpenter 76 Washington',
#  'Batts Matthew M, jersey pilot 148 York',
#  'Betts Rosanna, boarding house 72 Washington',
#  'Betts Wright C, machinist 105 Front (av n Kent av',
#  'Bctts Wm C, physician Myrtle n Carlton av and Flushing',
#  'Betts William YY, accountant Fulton House 12 Fulton',
#  'Beverly Elizabeth, 27 York',
#  "Beverly W'illiam, ship carpenter 27 York",
#  'Beyer Francis J, oyster saloon 61 Fu)ton',
#  'Bibrim William, Flatbush road n Prospect Hill',
#  'Bicker Frederick, shoemaker Myrtle av c Spencer (Place',
#  'Bicker YValter J, coal yard Columbia c Congress h 14 Sydney',
#  'Bickford Abraham, ink manufactory 41 Adelphi',
#  'Bickford William, carpenter 26 Lafayette',
#  'Bicknell Daniel, upholsterer 39 Myrtle av',
#  'Bicknell Isaac J, 36 Ferry N Y h Flatbush turnpike n Powers',
#  'Bidel Richard, 71 Poplar',
#  'Biddell James, shipmaster 33 Hicks',
#  'Bid dell John, mason 80 Fulton',
#  'Biddell Valentine, coach factory 52 Myrtle av c Jay',
#  'Biddle William, fur skin dresser Plymouth n Jay',
#  'Biden Edward A, accountant 134 Henry',
#  'Bidwell A C, boarding house 229 Hicks',
#  'Biers , physician Willoughby c Gold',
#  'BROOKLYN DIRECTORY. 41',
#  'Bierworth Leopold, merchant 40 New N Y h 85 State',
#  'Bigley J E, merchant N Y h 65 Hicks',
#  'Bigley William, 91 Henry',
#  'Biglow F, fur store N Y h 96 Hicks',
#  'Biglow F H, cap, hat and fur store 199 Fulton h 96 Hicks',
#  'Biglow J B, grocer 58 Hicks c Cranberry',
#  'Bill Charles E, merchant N Y h 119 Columbia n Clark',
#  ...]

# %% [markdown]
# ### Moving the [... down to the next row

# %%
import re
for index in range(0, len(data)):
    match = re.findall(r'\[.*$', data[index])
    if match:
        data[index + 1] = data[index + 1] + ' ' + str(match[0]).strip('[')
        data[index] = data[index].replace(str(match[0]), '')
    else:
        pass

# %% [markdown]
# ### Issues with Paranthesis
# - Adams J W, civil engineer Hoyt n State (Classon av
# - Addy Edward 50 Middagh (tionary 262 Fulton

# %% [markdown]
# Abbreviations h. stands for house, n, for near, c. for corner, op. for\n',
#  'opposite,b. for between

# %%
data[0:7]
# Out:
# ['HE ARNES’',
#  'BROOKLYN CITY',
#  'DIRECTORY.',
#  '1850-1851.',
#  'NOTE.—Names having a * are the names of colored people',
#  'Abbreviationsh. stands for house, n, for near, c. for corner, op. for',
#  'opposite,b. for between, The precise location of residences thus de-']

# %%
# Remove first 8 lines of the Entry
data = data[8:16081]

# %% [markdown]
# ### Occupations need to be separated from Address by ,

# %%
pattern = ', [A-Za-z]+ [0-9A-Z]'
for index in range(0, len(data)):
    if len(data[index]) <3:
        pass
    else:
        if re.findall(pattern, data[index]):
            x = str(re.findall(pattern, data[index]))
            y = str(x).replace(' ', ', ')
            z = y.replace(',,', ',')
            data[index] = data[index].replace(str(x), str(z))
            print(x)
            print(z)
            print(data[index])
# Out:
# [', shoemaker 1']
# [', shoemaker, 1']
# Abberly Richard, shoemaker 168 Hudson av
# [', mason D']
# [', mason, D']
# Abberly Samuel, mason Dean n Vanderbilt av
# [', carpenter 8']
# [', carpenter, 8']
# Abbey A C, carpenter 82 Poplar
# [', Columbia I']
# [', Columbia, I']
# ABBES HORATIO G, Columbia Institute for the education of
# [', merchant N']
# [', merchant, N']
# Abbey W S, merchant NYh Union n Court
# [', merchant 1']
# [', merchant, 1']
# Abbott Francis H, merchant 141 Front NYh Joralemon n Court
# [', milkman K']
# [', milkman, K']
# Abbott H B, milkman Kent av north
# [', laborer B']
# [', laborer, B']
# Abbott James, laborer Bond c State
# [', merchant 2']
# [', merchant, 2']
# Abbott John D, merchant 295.5 Pearl NYh 362 Atlantic n Hoyt
# [', furrier 7']
# [', furrier, 7']
# Abbott Moses, furrier 74 Concord
# [', butcher M']
# [', butcher, M']
# Abbott Samuel D, butcher Myrtle c Jay h 115 Johnson
# [', shoemaker 2']
# [', shoemaker, 2']
# Abburty John, shoemaker 261 Marshall
# [', accountant 3']
# [', accountant, 3']
# Abel E L, accountant 301 Gold
# [', sashmaker 2']
# [', sashmaker, 2']
# Aber Smith M, sashmaker 288 Hudson av
# [', shoemaker N']
# [', shoemaker, N']
# Abercrombie George, shoemaker Navy c Sands
# [', shoemaker 1']
# [', shoemaker, 1']
# Abercrombie John, shoemaker 116 Concord
# [', merchant N']
# [', merchant, N']
# Aborn Robert W, merchant NYh 180 Henry
# [', capmaker 5']
# [', capmaker, 5']
# Abraham David, capmaker 5 York
# [', laborer 3']
# [', laborer, 3']
# Abrahams Joseph, laborer 3 Kelsey’s alley
# [', seaman C']
# [', seaman, C']
# *Abrahams Thompson, seaman Clark’s alley n York
# [', laborer S']
# [', laborer, S']
# Abraham Patrick, laborer State c Smith
# [', carpenter 1']
# [', carpenter, 1']
# Abrams Valentine, carpenter 159 Gold
# [', laborer 7']
# [', laborer, 7']
# *Abrams Thomas, laborer 74 Jay
# [', widow 9']
# [', widow, 9']
# Acker Agnes, widow 97 Prospect
# [', widow H']
# [', widow, H']
# Acker Matilda, widow Hudson c Myrtle av
# [', printer 9']
# [', printer, 9']
# Ackerman James M, printer 90 Washington
# [', builder B']
# [', builder, B']
# Ackerman John M, builder Butler n Court
# [', tailor H']
# [', tailor, H']
# Ackerman John R, tailor Hoyt n Atlantic
# [', carpenter 2']
# [', carpenter, 2']
# Ackley James, carpenter 234 Hudson av
# [', lawyer 7']
# [', lawyer, 7']
# Ackley William B, lawyer 71 Nassau NYh 143 Duffield
# [', merchant 7']
# [', merchant, 7']
# Acosta John, merchant 76 Broad NYh 132 Sands
# [', blacksmith 2']
# [', blacksmith, 2']
# Adair James, blacksmith 246 Marshall
# [', printer 1']
# [', printer, 1']
# Adair William, printer 177 Gold
# [', merchant 3']
# [', merchant, 3']
# Adams Alexander, merchant 32 Pearl NYh 124 Smith
# [', carpenter P']
# [', carpenter, P']
# Adams Charles, carpenter Park n Clinton av
# [', tailor 3']
# [', tailor, 3']
# Adams Frederick L, tailor 36 State
# [', merchant N']
# [', merchant, N']
# Adams Innes C, merchant NYh Degraw op Strong Place
# [', merchant 1']
# [', merchant, 1']
# Adams James, merchant 18 South N Y h Schermerhorn n
# [', shoemaker P']
# [', shoemaker, P']
# Adams Philip P, shoemaker Pacific n Hoyt
# [', sailmaker L']
# [', sailmaker, L']
# Adams Samuel P, sailmaker Little c United States
# [', broker 7']
# [', broker, 7']
# Adams Thomas, broker 71 Wall NYh 316 Gold
# [', daguerreotyper M']
# [', daguerreotyper, M']
# Adams Thomas, daguerreotyper Myrtle av n Classon av
# [', moulder P']
# [', moulder, P']
# Adams William T, moulder Plymouth n Jay
# [', laborer 1']
# [', laborer, 1']
# Adams William, laborer 1 McKenney
# [', waiter 4']
# [', waiter, 4']
# *Adams Robert, waiter 43 Talman
# [', laborer 1']
# [', laborer, 1']
# Adderloy James, laborer 10 Vine
# [', laborer 3']
# [', laborer, 3']
# Adlum Thomas, laborer 3 York
# [', laborer 7']
# [', laborer, 7']
# Agan Patrick, laborer 77 Fork
# [', importer 1']
# [', importer, 1']
# Ainslie Francis, importer 150 Front NYh Clermont n
# [', taxidermist 1']
# [', taxidermist, 1']
# Akhurst John, taxidermist 15 Prospect
# [', shoemaker 9']
# [', shoemaker, 9']
# Alker J, shoemaker 95 Prospect Fulton av
# [', h S']
# [', h, S']
# Akin Isaac D, merch’t 10 Old Slip N Y, h Sackett n Clinton
# [', carpenter 1']
# [', carpenter, 1']
# Albertson Charles H, carpenter 110 Hudson av
# [', blockmaker 1']
# [', blockmaker, 1']
# Albertson Joseph R, blockmaker 114 Hudson av
# [', builders 6']
# [', builders, 6']
# Albertson & Simonson, builders 68 York
# [', tailor 4']
# [', tailor, 4']
# Alcorn William, tailor 43 Main
# [', widow 8']
# [', widow, 8']
# Alexander Frances, widow 80 High
# [', tailor F']
# [', tailor, F']
# Alexander Joseph, tailor Flushing c Franklin av
# [', milkman F']
# [', milkman, F']
# Alexander Joseph, milkman Flushing av n Spencer
# [', milkman S']
# [', milkman, S']
# Alexander Mark, milkman Spencer n Flushing av
# [', accountant M']
# [', accountant, M']
# Alexander William S, accountant Myrtle av a Steuben
# [', laborer 3']
# [', laborer, 3']
# Alger George F, laborer 3d av Gowanus
# [', mason 9']
# [', mason, 9']
# Allen Abraham, mason 93 Cranberry
# [', blacksmith W']
# [', blacksmith, W']
# Allen David, blacksmith Water n Fulton h 106 Bridge
# [', cooper 1']
# [', cooper, 1']
# Allen Edward, cooper 148 High
# [', widow 6']
# [', widow, 6']
# Allen Elizabeth, widow 63 Hudson av
# [', cooper 2']
# [', cooper, 2']
# Allen George, cooper 29 Talman
# [', agent N', ', h 6']
# [', agent, N', ', h, 6']
# Allen Hugh, agent N Y, h 67 Baltic
# [', mason I']
# [', mason, I']
# Allen Isaac, mason IS2 Jay
# [', laborer 3']
# [', laborer, 3']
# Allen John, laborer 3d av e Bridge road Gowanus
# [', merchant N']
# [', merchant, N']
# Allen John, merchant N Y' h 67 Baltic
# [', agent 1']
# [', agent, 1']
# Allen John, agent 157 Cedar N Y h 67 Baltic
# [', mason 3']
# [', mason, 3']
# Allen J Lewis, mason 359 Hudson av
# [', cooper 1']
# [', cooper, 1']
# Allen John, cooper 122 Adams c High
# [', grocer 2']
# [', grocer, 2']
# Allen N V, grocer 270 Washington c Myrtle av
# [', seaman 6']
# [', seaman, 6']
# Allen Peter, seaman 62 Front
# [', porter C']
# [', porter, C']
# Allen Robert, porter Columbia e Warren
# [', laborer P']
# [', laborer, P']
# Allen Robert, laborer Park n Vanderbilt av
# [', blacksmith 2']
# [', blacksmith, 2']
# Allen Robert, blacksmith 255 John
# [', shoemaker M']
# [', shoemaker, M']
# Allen Samuel, shoemaker Myrtle n Classon av h Classon n Flushing av
# [', nurse C']
# [', nurse, C']
# Allen Sarah, nurse Columbia c Warren
# [', butcher 3']
# [', butcher, 3']
# Allen W'illiam, butcher 3d av c 16th st Gowanus
# [', clerk C']
# [', clerk, C']
# Allen William H, clerk Classon n Flushing av
# [', LONG I']
# [', LONG, I']
# ALLEN & Co., LONG ISLAND GROCERY, 270 Washington e Myrtleav
# [', merchant N']
# [', merchant, N']
# Aller Amos, merchant N Y h 45 Willow
# [', printer D']
# [', printer, D']
# Alley Joseph B, printer Duffield n Fulton av
# [', grocers F']
# [', grocers, F']
# Allgeo & Linington, grocers Flatbush turnpike c Atlantic
# [', importer S']
# [', importer, S']
# Allien H V, importer S Maiden Lane NY h 182 Atlantic
# [', laborer W']
# [', laborer, W']
# Allison John, laborer Water n Bridge
# [', builder C']
# [', builder, C']
# Allison John P, builder Cottage place 106 Columbia
# [', salesman W']
# [', salesman, W']
# Allison W'illiam, salesman Wyckoff n Bond
# [', furrier B']
# [', furrier, B']
# Alshelsky Theodore, furrier Bergen n Powers
# [', carpenter D']
# [', carpenter, D']
# Althlser William, carpenter DeKalb av c Raymond
# [', cook L']
# [', cook, L']
# Alwick Jacob H, cook Livingston n Hoyt
# [', widow S']
# [', widow, S']
# Alvey Sarah, widow Smith c Bergen
# [', clerk 2']
# [', clerk, 2']
# Allyn Francis L, clerk 207 Front
# [', grocer F']
# [', grocer, F']
# Alpers Martin, grocer Fulton av c Gold
# [', artist P']
# [', artist, P']
# Alpin John, artist Prospect Hill
# [', grocer C']
# [', grocer, C']
# Alsgood Peter, grocer Carlton c Park av
# [', Red H']
# [', Red, H']
# Alway Edward, Red Hook
# [', Red H']
# [', Red, H']
# Al way John, Red Hook
# [', carpenter 3']
# [', carpenter, 3']
# Amberman Peter N, carpenter 380 Hudson av
# [', carpenter 1']
# [', carpenter, 1']
# Amberman Richard, carpenter 135 Nassau
# [', builder C']
# [', builder, C']
# Ambrose George, builder Court n Pacific
# [', cooper 1']
# [', cooper, 1']
# Amer William, cooper 18 Talman
# [', widow 2']
# [', widow, 2']
# Amies Maria, widow 2 Debevoise
# [', groeer 4']
# [', groeer, 4']
# Ammerman Nicholas, groeer 40 Carlton av
# [', Bugbies A']
# [', Bugbies, A']
# Ammon Samuel, Bugbies Alley n Fulton (N Y
# [', John J']
# [', John, J']
# AMERICAN HOTEL, 26 Fulton, John Jones Proprietor
# [', artist D']
# [', artist, D']
# Ames Daniel, artist Division n DeKalb av
# [', market C']
# [', market, C']
# Amy Daniel, market Court c Dean
# [', stonecutter 6']
# [', stonecutter, 6']
# Anderson Alexander, stonecutter 64 Pacific
# [', grocer 1']
# [', grocer, 1']
# Anderson Benjamin, grocer 155 Jay c Nassau
# [', architect 1']
# [', architect, 1']
# ANDERSON CHARLES F, architect 17 Park Place NY h Col-
# [', tailor 2']
# [', tailor, 2']
# Anderson David, tailor 234 Hudson av
# [', hostler 1']
# [', hostler, 1']
# Anderson Dennis, hostler 15 College Place
# [', mason B']
# [', mason, B']
# Anderson David, mason Bond n State
# [', widow 7']
# [', widow, 7']
# Anderson Ellen, widow 75 Prince (road e 9th st.
# [', clerk 9']
# [', clerk, 9']
# Anderson John, clerk 98 Boerum
# [', laborer W']
# [', laborer, W']
# Anderson John, laborer Willow c Pacific
# [', widow 1']
# [', widow, 1']
# Anderson Lucinda, widow 180 Nassau
# [', porter 6']
# [', porter, 6']
# *Anderson Barrett, porter 64 Jay
# [', laborer 6']
# [', laborer, 6']
# *Anderson William, laborer 64 Jay
# [', bookkeeper 1']
# [', bookkeeper, 1']
# Andree Frederick, bookkeeper 105 Washington
# [', merchant 5']
# [', merchant, 5']
# Andrews James, merchant 59 Broadway NYh Classon n
# [', butcher C']
# [', butcher, C']
# Andrews , butcher Columbia n Sackett
# [', butcher 4']
# [', butcher, 4']
# Andrews William, butcher 44 Baltic
# [', merchant 6']
# [', merchant, 6']
# Angrave Clifton, merchant 62 Pine NYh 191 Clinton
# [', constable 2']
# [', constable, 2']
# Angus Henry, constable 2nd Ward 39 Front
# [', silversmith A']
# [', silversmith, A']
# Angus William J, silversmith Amity n Court
# [', broker H']
# [', broker, H']
# Ansell Henry, broker Hicks c Poplar
# [', merchant 2']
# [', merchant, 2']
# Anthony David C, merchant 24 Cedar N Y h 97 Concord
# [', widow R']
# [', widow, R']
# Anthony Hester, widow Red Hook
# [', baker C']
# [', baker, C']
# Antony Fhilip, baker Cranberry c Henry (95 Myrtle av
# [', carpenter M']
# [', carpenter, M']
# Applegate Lewis, carpenter Myrtle av n Raymo,nd
# [', butcher M']
# [', butcher, M']
# Applegate William R, butcher Myrtle ay n Raymond
# [', clcrk 1']
# [', clcrk, 1']
# Appleton Samuel B, clcrk 143 Fulton
# [', painter B']
# [', painter, B']
# Appleyard Thomas, painter Bergen n 4th av
# [', carman T']
# [', carman, T']
# Appleyard William, carman Tillary n Navy
# [', blacksmith 6']
# [', blacksmith, 6']
# Arbona Francis R, blacksmith 60 Carlton n Myrtle av
# [', laborer A']
# [', laborer, A']
# Arbuckle Andrew, laborer Adams b Watcr and Front
# [', merchant 3']
# [', merchant, 3']
# Archer George B, merchant 38 Concord
# [', painter H']
# [', painter, H']
# Arkness Anthony, painter Hamilton av n Ferry (Front
# [', merchant 1']
# [', merchant, 1']
# Arms Charles, merchant 159 Pearl N Y h 69 Orange
# [', plasterer 4']
# [', plasterer, 4']
# Armshaw Richard, plasterer 41 Main
# [', druggist N']
# [', druggist, N']
# Armstrong Benjamin, druggist N Y h 46 Sauds
# [', tinman 1']
# [', tinman, 1']
# Armstrong John, tinman 15 Prince
# [', laborer P']
# [', laborer, P']
# Armstrong John, laborer Pacific n Vanderbilt av
# [', laborer B']
# [', laborer, B']
# Armstrong Patrick, laborer Bridge c Water
# [', merchant 6']
# [', merchant, 6']
# Arnold Daniel H, merchant 60 Pine N Y h 38 Pierrepont
# [', mercht 3']
# [', mercht, 3']
# Arnold Edward H, mercht 34 Beaver N Y h 65 Joralemon
# [', laborer 2']
# [', laborer, 2']
# Arnold George, laborer 25 Green lane
# [', mercht 1']
# [', mercht, 1']
# Arnold George, mercht 147 Broadway N Y h 100 Middagh
# [', carpenter C']
# [', carpenter, C']
# Arnold Samuel, carpenter Court n Degraw
# [', undertaker B']
# [', undertaker, B']
# Arnold William M, undertaker Boerum n Pacific
# [', agent P']
# [', agent, P']
# Arrents Edward, agent Powers n Dean (Atlantic
# [', merchant 1']
# [', merchant, 1']
# Arrosmith Benjamin E, merchant 145 Broad NYh Hoyt n
# [', engineer 2']
# [', engineer, 2']
# Arthur William, engineer 254 Gold n Myrtle av
# [', widow 1']
# [', widow, 1']
# Ash Ann, widow 101 Nassau
# [', widow 4']
# [', widow, 4']
# *Ash Jane, widow 41 Hicks c Middagh
# [', mason H']
# [', mason, H']
# Ashfield James, mason Hoyt n Pacific
# [', nurse 8']
# [', nurse, 8']
# Ashman Mrs, nurse 83 Cranberry
# [', widow C']
# [', widow, C']
# Ashton Catharine, widow Cole st n Hamilton av
# [', flagger 4']
# [', flagger, 4']
# Ashworth John, flagger 48 Green lane
# [', agent 7']
# [', agent, 7']
# Askham John, agent 71 Nassau
# [', shoemaker P']
# [', shoemaker, P']
# Aspenall William, shoemaker Park c Franklin av h Flushing
# [', cooper 4']
# [', cooper, 4']
# Asfen Wm, cooper 42 Water N Y h 99 Jay
# [', porter 5']
# [', porter, 5']
# Atfrold William, porter 50 Pacific n Classon av
# [', merchant 3']
# [', merchant, 3']
# Atkins Edwin, merchant 38 South N Y h 9 Monroe place
# [', plasterer S']
# [', plasterer, S']
# Atkins Job, plasterer Schermerhorn n Bond
# [', daguerreotypist 2']
# [', daguerreotypist, 2']
# Atkins Joseph, daguerreotypist 219 Fulton
# [', mason 1']
# [', mason, 1']
# Atkins Joshua, mason 10 Carll
# [', merchant 3']
# [', merchant, 3']
# Atkins Joshua, merchant 38 South N Y h 9 Monroe Place
# [', shoemaker B']
# [', shoemaker, B']
# Atkins Samuel H, shoemaker Boerum c Pacific
# [', shoemaker 2']
# [', shoemaker, 2']
# Atkins William, shoemaker 254 Atlantic
# [', carpenter N']
# [', carpenter, N']
# Atkinson B, carpenter Navy n De Kalb av
# [', grocer 3']
# [', grocer, 3']
# Atkinson James, grocer 330 Atlantic e Hoyt
# [', merchant 1']
# [', merchant, 1']
# Atkinson John P, merchant 105 Wall N Y h 26 Garden
# [', merchant N']
# [', merchant, N']
# Atkinson O, merchant N Y h 4 Union Place
# [', carman 1']
# [', carman, 1']
# Atkinson Robert, carman 14 Plymouth
# [', clerk 2']
# [', clerk, 2']
# Atkinson William, clerk 206 Washington
# [', grocer 1']
# [', grocer, 1']
# Atterbury William, grocer 14 Tillary
# [', physician R']
# [', physician, R']
# Atwater David F, physician Remsen 1 door from Clinton
# [', merchant N']
# [', merchant, N']
# Atwater Leonard D, merchant N Y h 42 Concord
# [', accountant 2']
# [', accountant, 2']
# Auburn Thomas E, accountant 251 Gold
# [', storage F']
# [', storage, F']
# Auger John B, storage Furman h 102 Joralemon
# [', grocers 1']
# [', grocers, 1']
# Auld & Randall, grocers 10 Hamilton av
# [', carpenter 7']
# [', carpenter, 7']
# Austin John, carpenter 74 Water
# [', tinsmith W']
# [', tinsmith, W']
# Austin Joseph, tinsmith Washington c York
# [', carpenter 2']
# [', carpenter, 2']
# Austin Matthew, carpenter 2 Kelsey’s alley
# [', widow 5']
# [', widow, 5']
# Austin S E, widow 52 Willow (182 Jay
# [', marketman W']
# [', marketman, W']
# Austin Theodore, marketman Washington market NYh
# [', seaman 1']
# [', seaman, 1']
# Avery John R, seaman 11 Cottage row Water
# [', clerk A']
# [', clerk, A']
# Avery R H, clerk Adelphi n Jamaica av (Smith
# [', mason 1']
# [', mason, 1']
# Avery Timothy D, mason 110 Tillary
# [', painter 1']
# [', painter, 1']
# Avila John, painter 134 Nassau
# [', tailor 9']
# [', tailor, 9']
# Avis William T, tailor 94 Duffield
# [', merchant N']
# [', merchant, N']
# Ayres Daniel, merchant NYh 131 Columbia
# [', merchant 4']
# [', merchant, 4']
# Ayres Robert, merchant 46 Front N Y h 28 Joralemon
# [', broker 4']
# [', broker, 4']
# Babad Henry, broker 43 New NYh 422 Atlantic n Powers
# [', distiller 4']
# [', distiller, 4']
# Bach John C, distiller 48 Sands
# [', widow 1']
# [', widow, 1']
# Back Margaret, widow 138 Nassau (Carlton n Myrtle av
# [', carpenter 2']
# [', carpenter, 2']
# Backus Samuel W, carpenter 220 Navy
# [', laborer W']
# [', laborer, W']
# Bacon James, laborer Water n Jay
# [', clerk 2']
# [', clerk, 2']
# Bacon James, clerk 2 Butler
# [', pastor R']
# [', pastor, R']
# Bacon Rev David W, pastor R C Ch of the Assumption 82
# [', engraver 1']
# [', engraver, 1']
# BADEAU ISAAC, engraver 102 Nassau c Ann NYh 127 Prospect
# [', chemist 1']
# [', chemist, 1']
# Badcock Henry, chemist 1 Hudson av
# [', accountant 1']
# [', accountant, 1']
# Badger George S, accountant 138 Sands
# [', carpenter 7']
# [', carpenter, 7']
# Bagley Dominick, carpenter 7 Prince
# [', carman C']
# [', carman, C']
# Bagley James, carman Carll n Willoughby
# [', laborer R']
# [', laborer, R']
# Bagley Patrick, laborer Raymond n Tillary
# [', laborer 2']
# [', laborer, 2']
# *Bagley George, laborer 285 Hudson av
# [', storage U']
# [', storage, U']
# Bagnell G R, storage Union b Hicks and Columbia
# [', laborer N']
# [', laborer, N']
# Bahan Edward, laborer Navy n Bolivar
# [', Franklin H']
# [', Franklin, H']
# Bailey Aretus, Franklin House 15 Fulton c Water
# [', widow W']
# [', widow, W']
# Bailey Elizabeth, widow Water c Hudson av
# [', engineer C']
# [', engineer, C']
# Bailey H F, engineer Classon n Flushing av (280 Jay
# [', laborer 2']
# [', laborer, 2']
# Bailey John H, laborer 202 Prospect
# [', accountant 1']
# [', accountant, 1']
# Bailey John Townsend, accountant 111 Nassau
# [', furrier 1']
# [', furrier, 1']
# Bailey Joseph P, furrier 154 Santis
# [', Apothecaries H']
# [', Apothecaries, H']
# BAILEY WILLIAM, Apothecaries Hall 206 Fulton c Pineapple h 22 Sands
# [', proprietors F']
# [', proprietors, F']
# Bailey & Baldwin, proprietors Franklin House 15 Fulton c
# [', waiter H']
# [', waiter, H']
# *Bailey Benjamin, waiter Hart’s alley n Gold
# [', saddler 2']
# [', saddler, 2']
# Bainbridge John, saddler 284 Atlantic
# [', stationer 4']
# [', stationer, 4']
# Bainbridge Richard, stationer 47 Cliff N Y h 105 Clinton
# [', mason 9']
# [', mason, 9']
# Baird Robert, mason 9 Jay
# [', contractor W']
# [', contractor, W']
# Baird Wil)iam, contractor Wyckoff n Smith
# [', carpenter L']
# [', carpenter, L']
# Baisley Lewis, carpenter Livingston n Nevins
# [', carpenter N']
# [', carpenter, N']
# Baisley Nehemiah, carpenter Nevins n Schermerhorn 309 Fulton
# [', carpenter D']
# [', carpenter, D']
# Baisley Peter, carpenter Dean n Powers
# [', gardener S']
# [', gardener, S']
# Baisley Samuel, gardener Spencer n Flushing av
# [', mason 1']
# [', mason, 1']
# Baisley Thomas, mason 118 Willoughby
# [', merchant 5']
# [', merchant, 5']
# Baker Augustus D, merchant 5 South NYh 103 Clinton
# [', agent F']
# [', agent, F']
# Baker Charles H, agent Furman n Joralemon
# [', grocer 6']
# [', grocer, 6']
# Baker Chas S, grocer 6 Linden row Fulton h 20 Willoughby
# [', physician 2']
# [', physician, 2']
# Baker Daniel, physician 26 Myrtle av
# [', architect 2']
# [', architect, 2']
# Baker Edward, architect 222 Henry
# [', carpenter 2']
# [', carpenter, 2']
# Baker Edwin, carpenter 225 Atlantic h 8 Garden
# [', pilot 7']
# [', pilot, 7']
# Baker Elisha B, pilot 73 Pineapple
# [', clerk 9']
# [', clerk, 9']
# Baker Henry, clerk 9 Degraw
# [', blacksmith P']
# [', blacksmith, P']
# Baker George E, blacksmith Pacific n Court h Baltic n Smith
# [', cooper 5']
# [', cooper, 5']
# Baker Hiram, cooper 51 Tillary
# [', publisher 1']
# [', publisher, 1']
# Baker Isaac D, publisher 145 Nassau N Y h 13 Schermerhorn
# [', mason 1']
# [', mason, 1']
# Baker James A, mason 111 Willoughby
# [', tailor 1']
# [', tailor, 1']
# Baker James, tailor 15th st n Sth av Gowanus
# [', grocers 6']
# [', grocers, 6']
# Baker Jesse M & Co, grocers 6 Linden row Fulton h 20 Willoughby c Pearl
# [', Van B']
# [', Van, B']
# Baker John, Van Brunt st Red Hook
# [', merchant 1']
# [', merchant, 1']
# Baker John H, merchant 178 Washington c Concord
# [', carpenter 3']
# [', carpenter, 3']
# Baker Lewis, carpenter 3 Kelsey’s alley
# [', laborer 3']
# [', laborer, 3']
# Baker Lewis, laborer 3 Kelsey’s alley
# [', widow 1']
# [', widow, 1']
# Baker Mary, widow 110 Fulton
# [', grocer N']
# [', grocer, N']
# Baker Smith, grocer NY h 22 Henry
# [', laborer 1']
# [', laborer, 1']
# Baker Thomas, laborer 11 State
# [', machinist K']
# [', machinist, K']
# Baker William H, machinist Kent av North
# [', clerk 1']
# [', clerk, 1']
# Baker William E, clerk 10 Cottage row Furman
# [', carpenter 1']
# [', carpenter, 1']
# Balance Joseph, carpenter 193 Myrtle av
# [', mason M']
# [', mason, M']
# Baldwin Bedell, mason Myrtle av c Steuben
# [', grocer 1']
# [', grocer, 1']
# Baldwin Benjamin, grocer 148 High
# [', grocers B']
# [', grocers, B']
# Baldwin & Burtis, grocers Bridge c High
# [', mason 3']
# [', mason, 3']
# Baldwin Caleb H, mason 345 Gold
# [', merchant 8']
# [', merchant, 8']
# Baldwin C P, merchant 8 Cedar NY h 35 Sydney place
# [', cooper 1']
# [', cooper, 1']
# Baldwin David M, cooper 117 Concord
# [', cooper 7']
# [', cooper, 7']
# Baldwin David W, cooper 71 C'oncord
# [', Franklin H']
# [', Franklin, H']
# Baldwin Ezekiel, Franklin House 15 Fulton
# [', grocer B']
# [', grocer, B']
# Baldwin Ezra, grocer Bridge c High h 162 Bridge
# [', mason 1']
# [', mason, 1']
# Baldwin Garret, mason 114 Willoughby
# [', cooper 1']
# [', cooper, 1']
# Baldwin James H, cooper 117 Concord
# [', carpenter 8']
# [', carpenter, 8']
# Baldwin John, carpenter 86 Adams
# [', blacksmith F']
# [', blacksmith, F']
# Baldwin Joseph, blacksmith Flushing av op Spencer
# [', milliner 1']
# [', milliner, 1']
# Baldwin Miss Maria, milliner 111 Fulton
# [', marketman 4']
# [', marketman, 4']
# Baldwin Moses, marketman 46 Front
# [', carpenter C']
# [', carpenter, C']
# Baldwin M, carpenter Cumberland n Park av
# [', blacksmith B']
# [', blacksmith, B']
# Baldwin Platt, blacksmith Baltic c Smith
# [', seaman 2']
# [', seaman, 2']
# Baldwin Roswell B, seaman 299 Adams
# [', milkman P']
# [', milkman, P']
# Baldwin Platt, milkman Putnam c Bedford av
# [', dressmaker S']
# [', dressmaker, S']
# Baldwin Sarah, dressmaker Schermerhorn n Nevins
# [', laborer 2']
# [', laborer, 2']
# Baldwin Turner, laborer 27 Green lane n Prospect
# [', clerk 5']
# [', clerk, 5']
# Balfe John R, clerk 56 Baltic n Smith
# [', baker C']
# [', baker, C']
# Balfe Patrick, baker Columbia c Pacific
# [', merchant N']
# [', merchant, N']
# Balieff Robert, merchant N Y h 163 Washington
# [', milkman B']
# [', milkman, B']
# Ball Andrew, milkman Bedford n DeKalb av
# [', M D', ', office M']
# [', M, D', ', office, M']
# BALL GEORGE C, M D, coroner, office Montague p)ace n Court
# [', carpenter F']
# [', carpenter, F']
# Ball Reuben, carpenter F)atbush turnpike c Nevins
# [', shoemakor 2']
# [', shoemakor, 2']
# Bail William, shoemakor 214 Raymond
# [', laborer W']
# [', laborer, W']
# Ballans William, laborer Water n Bridge
# [', ferryman 8']
# [', ferryman, 8']
# Ballantine James, ferryman 82 Tillary
# [', publisher N']
# [', publisher, N']
# Ballard Rev J, publisher N Y Recorder, 240 Pearl c Johnson
# [', furrier 1']
# [', furrier, 1']
# Ballard L, furrier 128 Water N Y h 98 Clinton
# [', accountant 4']
# [', accountant, 4']
# Balmano Robert, accountant 4 Dcgraw n Court
# [', widow 9']
# [', widow, 9']
# Balser Mary, widow 91 Hudson av
# [', pilot 7']
# [', pilot, 7']
# Balsor John, pilot 74 Washington
# [', stevedore 1']
# [', stevedore, 1']
# Bamber John, stevedore 196 Front
# [', reporter 1']
# [', reporter, 1']
# Banker Abraham, reporter 102 Concord
# [', hatter F']
# [', hatter, F']
# Bancroft Horace, hatter Flushing n Kent av
# [', laborer F']
# [', laborer, F']
# Banhart Christian, laborer Flushing n Franklin av
# [', laborer U']
# [', laborer, U']
# Banks George, laborer Union n Van Brunt
# [', widow 2']
# [', widow, 2']
# Banks Ma.y, widow 270 Hicks n State
# [', laborer 2']
# [', laborer, 2']
# *Banks Peter, laborer 266 Marshall
# [', widow R']
# [', widow, R']
# Bannen Bridget, widow Raymond n Myrtle av
# [', contractor D']
# [', contractor, D']
# Bannen Thomas, contractor Dikeman st Red Hook
# [', mason 1']
# [', mason, 1']
# Bannon Daniel, mason 130 Tillary
# [', laborer R']
# [', laborer, R']
# Bannon Michael, laborer Raymond n DeKalb av
# [', clerk R']
# [', clerk, R']
# Banta John P, clerk Red Hook Place n Fnlton av
# [', laborer P']
# [', laborer, P']
# *Banyan Benjamin, laborer Pacific n Court
# [', engineer 3']
# [', engineer, 3']
# Barber John, engineer 30 Hicks
# [', speculator C']
# [', speculator, C']
# Barber Joseph, speculator Cumberland n Myrtle av
# [', bookbinder 1']
# [', bookbinder, 1']
# Barber Robert, bookbinder 186 Water n Hudson av
# [', merchant 7']
# [', merchant, 7']
# Barber Samuel, merchant 79 Water NYh 194 Atlantic
# [', barkeeper 8']
# [', barkeeper, 8']
# Barber Willard, barkeeper 84 Fulton
# [', bookbinder 2']
# [', bookbinder, 2']
# BARBER WILLIAM S, bookbinder 22 High
# [', superintendent B']
# [', superintendent, B']
# Bare David, superintendent Brooklyn City Hospital Hudson
# [', merchant 2']
# [', merchant, 2']
# Barker David S, merchant 22 Pine N Y h 32 Willoughby
# [', milkman C']
# [', milkman, C']
# Barker Jacob, milkman Clove rd Bedford
# [', painter 2']
# [', painter, 2']
# Barker John, painter 228 Hudson av
# [', tailor 2']
# [', tailor, 2']
# Barker John, tailor 215 Fulton c Sprague Place
# [', Van B']
# [', Van, B']
# Barker Josiah H, Van Brunt st Red Hook
# [', accountant 1']
# [', accountant, 1']
# Barker Richard, accountant 110 Degraw
# [', shoemaker 8']
# [', shoemaker, 8']
# Barker Stephen W, shoemaker 89 Main
# [', carpenter 2']
# [', carpenter, 2']
# Barker Sylvester, carpenter 206 Bridge
# [', shipmaster 7']
# [', shipmaster, 7']
# Barkman F J W, shipmaster 73 Nassau
# [', clerk 2']
# [', clerk, 2']
# Barkuloo Abraham, clerk 257 Gold
# [', carman S']
# [', carman, S']
# Barkuloo Henry, carman Shermerhoin n Power.s
# [', widow 2']
# [', widow, 2']
# Barkuloo Maria, widow 213 Washington
# [', sawyer 2']
# [', sawyer, 2']
# Barlow Michael, sawyer 201 High
# [', clerk 1']
# [', clerk, 1']
# Barlow William If, clerk 14 Douglas
# [', shoemaker B']
# [', shoemaker, B']
# Bannon Michael, shoemaker Bridge c Tillary
# [', lawyer N']
# [', lawyer, N']
# Barnard D P, lawyer N Y h 66 Court (Bond
# [', jobber 9']
# [', jobber, 9']
# Barnard J W, jobber 93 William NYh Schermerhorn n
# [', widow 1']
# [', widow, 1']
# Barnard Mary, widow 129 Duffield n Willoughby
# [', accountant N']
# [', accountant, N']
# Barnes Alfred S, accountant N Y h 22 Garden
# [', sailmaker S']
# [', sailmaker, S']
# Barnes C, sailmaker Schermerhorn b Hoyt and Smith
# [', watchmaker 1']
# [', watchmaker, 1']
# Barnes Charles T, watchmaker 133 Nassau
# [', joiner 1']
# [', joiner, 1']
# Barnes Chauncey, joiner 15 High
# [', stevedore 9']
# [', stevedore, 9']
# Barnes David A, stevedore 98 Smith n Warren
# [', painter 1']
# [', painter, 1']
# Barnes Henry, painter 16 Myrtle av
# [', merchant N']
# [', merchant, N']
# Barnes Henry W, merchant N Y h 113 Henry
# [', tinsmith S']
# [', tinsmith, S']
# Barnes Joseph, tinsmith Spencer n Willoughby
# [', painter N']
# [', painter, N']
# Barnes William M, painter Navy c Delialb av
# [', brushmaker 1']
# [', brushmaker, 1']
# Barnett Henry, brushmaker 19 State
# [', stereotyper 8']
# [', stereotyper, 8']
# Barnett John, stereotyper 88 Middagh
# [', lawyer 2']
# [', lawyer, 2']
# Barney Hiram, lawyer 29 Wall N Y h 70 Pierrepont
# [', builder 1']
# [', builder, 1']
# Barney James B, builder 115 Myrtle av
# [', mason W']
# [', mason, W']
# Barney John, mason Warren n Smith
# [', widow 4']
# [', widow, 4']
# Barney Penelope, widow 41 Stanton
# [', cutter 8']
# [', cutter, 8']
# Barnsdall John, cutter 80 Cherry N Y h 56 Adams
# [', clothier 2']
# [', clothier, 2']
# Barnum Charles, clothier 252 Pearl N Y' h 17 Myrtle av
# [', teacher 1']
# [', teacher, 1']
# Barr , teacher 147 Hicks
# [', baker 8']
# [', baker, 8']
# Barr John, baker 85 Cranberry
# [', laborer 1']
# [', laborer, 1']
# Barr John, laborer 1 Hall’s buildings Furman
# [', coachmaker 2']
# [', coachmaker, 2']
# Barre Tobias, coachmaker 22 Henry
# [', shipmaster 2']
# [', shipmaster, 2']
# Barrell George, shipmaster 234 Bridge
# [', laborer N']
# [', laborer, N']
# Barrett Andrew, laborer Navy n Park av
# [', painter 7']
# [', painter, 7']
# Barrett George, painter 72 Atlantic
# [', locksmith 1']
# [', locksmith, 1']
# Barrett John B, locksmith 184 York
# [', porter D']
# [', porter, D']
# Barrctt Lewis A, porter DeKalb av n Bolivar
# [', carpenter 7']
# [', carpenter, 7']
# Barrett Peter M, carpenter 75 Pacific n Boerum
# [', tailor 6']
# [', tailor, 6']
# Barrett William, tailor 6 Kelsey’s alley
# [', glazier 1']
# [', glazier, 1']
# Barrick Nathan, glazier 150 Concord
# [', grocer C']
# [', grocer, C']
# Barrin Joseph, grocer Columbia c Amity
# [', laborer 2']
# [', laborer, 2']
# Barron James, laborer 221 Hudson av
# [', ranges 2']
# [', ranges, 2']
# Barrows Ebenezer, ranges 228 Water NYh 196 Pearl
# [', painter N']
# [', painter, N']
# Barrowsky Charles E, painter Navy n Myrtle av
# [', laborer 2']
# [', laborer, 2']
# Barry Arthur, laborer 2 Elizabeth
# [', laborer 6']
# [', laborer, 6']
# Barry Dennis, laborer 62 Front
# [', painter 2']
# [', painter, 2']
# Barry YVilliam H, painter 28 Boerum
# [', merchant 9']
# [', merchant, 9']
# Barstow Caleb, merchant 98 Pine N Y h 20 Sands
# [', merchant 9']
# [', merchant, 9']
# Barstow Henry W, merchant 98 Pine N Y h 18 Sands
# [', mason D']
# [', mason, D']
# Barter Joseph, mason Dean n Boerum
# [', cigarmaker 3']
# [', cigarmaker, 3']
# Barth Richard L, cigarmaker 33 Hudson av
# [', laborer 1']
# [', laborer, 1']
# Bartley Peter, laborer 13 State
# [', grocer 4']
# [', grocer, 4']
# Bartlett Gamaliel, grocer 4 Front N Y h 21 Joralemon
# [', mason 7']
# [', mason, 7']
# Barter John, mason 74 Harrison
# [', carpenter 2']
# [', carpenter, 2']
# Barton John B, carpenter 25 Adelphi
# [', blacksmith 2']
# [', blacksmith, 2']
# Barton Robert, blacksmith 233 Hudson av
# [', carpenter 4']
# [', carpenter, 4']
# Barton William, carpenter 47 Butler (Columbia
# [', merchant 1']
# [', merchant, 1']
# Barton W'illiam, merchant 18 Cliff N Yh9 Colonade row
# [', printer 1']
# [', printer, 1']
# Barton William, printer 177 Nassau
# [', carman 1']
# [', carman, 1']
# Bartow Benjamin P, carman 165 Hudson av (ingtoa
# [', carpenter 7']
# [', carpenter, 7']
# Bartow William E, carpenter 71 Concord
# [', carpenter 3']
# [', carpenter, 3']
# Basiorth Enos, carpenter 36 Prince
# [', druggist 1']
# [', druggist, 1']
# Bassett Francis M, druggist 158 Atlantic
# [', merchant N']
# [', merchant, N']
# Bassett Isaac H, merchant N Y h 75 Remsen n Henry
# [', locksmith 3']
# [', locksmith, 3']
# Bassett John, locksmith 35 Hudson av
# [', merchant 2']
# [', merchant, 2']
# Bassett L D, merchant 25 South NYh Dean n Nevins
# [', widow V']
# [', widow, V']
# Bassett Susannah, widow Vanderbilt av n Dean
# [', carpenter 2']
# [', carpenter, 2']
# Baston Richard, carpenter 273 Pearl
# [', grocer 3']
# [', grocer, 3']
# Batcheler Washington A, grocer 3d avb 15th and 16th stGo-
# [', grocers 1']
# [', grocers, 1']
# Batcheler & Vail, grocers 19th st c 3d av Gowanus
# [', Red H']
# [', Red, H']
# Bate Lawrence, Red Hook
# [', merchant 1']
# [', merchant, 1']
# Bate Thomas, merchant 103 Maiden Lane N Y h 76 Adams
# [', merchant 1']
# [', merchant, 1']
# Bate Thomas Henry, merchant 103 Maiden Lane NYh
# [', mason P']
# [', mason, P']
# Bates Andrew, mason Pacific n Smith (Park av
# [', merchant N']
# [', merchant, N']
# Bates Henry, merchant N Y h 50 State
# [', Red H']
# [', Red, H']
# Bates John, Red Hook
# [', laborer 3']
# [', laborer, 3']
# Bates John, laborer 37 Hudson av
# [', printer F']
# [', printer, F']
# Bates YVilliam, printer Fulton c Myrtle av
# [', distiller O']
# [', distiller, O']
# Bates William, distiller Oxford st n Jamaica rd
# [', widow 7']
# [', widow, 7']
# Bath Lydia M, widow 71 Hudson av
# [', upholsterer 1']
# [', upholsterer, 1']
# Batterson Smith, upholsterer 154 Atlantic
# [', widow 1']
# [', widow, 1']
# Battle Mary, widow 183 Prospect
# [', ferryman 1']
# [', ferryman, 1']
# Baulsir Conrad, ferryman 11 Carlton av
# [', shoemaker 2']
# [', shoemaker, 2']
# Bavel Charles, shoemaker 25 Sackett
# [', shipmaster 2']
# [', shipmaster, 2']
# Baxter Alvan, shipmaster 20 Tillary
# [', grocer 6']
# [', grocer, 6']
# Baxter A S, grocer 68 Water NYh Clinton n Degraw
# [', mercht 1']
# [', mercht, 1']
# Baxter Charles H, mercht 1-13 Maiden Lane N Y h 42 Court
# [', carpenter 2']
# [', carpenter, 2']
# Baxter John, carpenter 29 Charles n York
# [', laborer I']
# [', laborer, I']
# Baxter John, laborer II Prospect
# [', carman C']
# [', carman, C']
# Baxter John, carman Columbiab State and Joralemon
# [', ferryman 4']
# [', ferryman, 4']
# Bayard Thomas, ferryman 48 Bergen n Smith
# [', widow 1']
# [', widow, 1']
# *Bayard Margaret, widow 18 Ilartt’s Alley (low Place
# [', merchant 3']
# [', merchant, 3']
# Bayaud John, merchant 37 South William N Y h 35 Wil-
# [', contractor 9']
# [', contractor, 9']
# Bayley John, contractor 95 Carll (108 Livingston
# [', broker 3']
# [', broker, 3']
# Baylis Abraham B, broker 30 Merchants Exchange NYh
# [', huxter W']
# [', huxter, W']
# Baylis Gilbert C, huxter Washington market N Y h 101 Jay
# [', builder 8']
# [', builder, 8']
# Baylis Thos, builder 83 Washington h Joralemon n Henry
# [', gardener C']
# [', gardener, C']
# Baylis Thomas, gardener Clove road Bedford
# [', editor N']
# [', editor, N']
# Beach Alfred E, editor N Y Sun 73 Columbia
# [', merchant 7']
# [', merchant, 7']
# Beach Evan, merchant 73 William N Y h 43 Cranberry
# [', merchant 1']
# [', merchant, 1']
# Beach Harvey, merchant 15 Cortlandt N Y h 59 Hoyt
# [', grocer 2']
# [', grocer, 2']
# Beach Lewis, grocer 23 Myrtle av c Pearl h 34
# [', merchant N']
# [', merchant, N']
# Beach William, merchant NYh 266 Jay
# [', clerk 1']
# [', clerk, 1']
# Beal John C, clerk 124 Nassau
# [', merchant 2']
# [', merchant, 2']
# Beal John, merchant 22 Degraw n Smith
# [', cooper D']
# [', cooper, D']
# Beam Abraham U, cooper Dean n Smith
# [', baker M']
# [', baker, M']
# Beam Henry, baker Myrtle c Nostrand av
# [', cooper 1']
# [', cooper, 1']
# Boam John, cooper 130 Broad N Y h 101 State
# [', widow 9']
# [', widow, 9']
# Beam Louisa, widow 99 State
# [', attorney 8']
# [', attorney, 8']
# Beams B J, attorney 8 Tillary
# [', laborer 2']
# [', laborer, 2']
# Bean Hugh, laborer 22d st n 3d av Gowanus
# [', gardener P']
# [', gardener, P']
# Beaney Peter, gardener Pacific n Oxford
# [', shoemaker 3']
# [', shoemaker, 3']
# Beard Job, shoemaker 310 Atlantic
# [', contractor 3']
# [', contractor, 3']
# Beard William, contractor 34 Wyckoff
# [', clerk 1']
# [', clerk, 1']
# Beare William H, clerk 15 Stone NYh Hoyt n Statc
# [', machinist 1']
# [', machinist, 1']
# Beasley Edward, machinist 168 Pearl
# [', cartman 1']
# [', cartman, 1']
# Beatty Alexander, cartman 108 High
# [', cooper J']
# [', cooper, J']
# Beatty John, cooper Jay c Front
# [', printer S']
# [', printer, S']
# Beatty Mark, printer Sands n Navy
# [', bookbinder 8']
# [', bookbinder, 8']
# Beatty Robert Jr, bookbinder 80 Wall N Y h 107 Concord
# [', shoemaker 4']
# [', shoemaker, 4']
# Beatty Samuel, shoemaker 40 Prince
# [', painter F']
# [', painter, F']
# Beaty Andrew, painter Front n Jay
# [', groccr F']
# [', groccr, F']
# Beaty John, groccr Front c Jay
# [', grocer 2']
# [', grocer, 2']
# Beaumon Benjamin, grocer 21st st n 4th av Gowanus
# [', pedlar H']
# [', pedlar, H']
# Beaumont James, pedlar Hamilton st Red Hook
# [', engineer 2']
# [', engineer, 2']
# Beaumont Victor, engineer 296 Atlantic
# [', importer H']
# [', importer, H']
# Becar Noel J, importer Henry c Warren
# [', merchant 9']
# [', merchant, 9']
# Bechtel J D, merchant 90 Front N Y h 113 Livingston
# [', locksmith 1']
# [', locksmith, 1']
# Beckett Henry, locksmith 100 Orange
# [', accountant 9']
# [', accountant, 9']
# Bedell Cadwallader A, accountant 98 Duffield
# [', tanner 2']
# [', tanner, 2']
# Bedell Daniel, tanner 21 Carlton av
# [', widow C']
# [', widow, C']
# Bedell Mrs E, widow Classon n Flushing av
# [', carman C']
# [', carman, C']
# Bedell Henry, carman Classon n Myrtle av
# [', clerk 1']
# [', clerk, 1']
# Bedell Jacob M, clerk 118 Gold
# [', carman 2']
# [', carman, 2']
# Bedell Moses, carman 265 Hudson av
# [', merchant 1']
# [', merchant, 1']
# Bedell Mott, merchant 104 Wall N Y h 33 Cranberry
# [', blacksmith B']
# [', blacksmith, B']
# Bedell Richard, blacksmith Bridge c Sands
# [', carpenter 4']
# [', carpenter, 4']
# Bedell Stephen, carpenter 43 Adelphi
# [', shipsmith 5']
# [', shipsmith, 5']
# Bedell Valentine, shipsmith 57 York
# [', carver H']
# [', carver, H']
# Bedford Edward, carver Hudson c DeKalb av
# [', widow F']
# [', widow, F']
# Beebe Eliza, widow Flushing av n Franklin av
# [', clerk 2']
# [', clerk, 2']
# Beebe O A, clerk 227 Atlantic
# [', ropemaker K']
# [', ropemaker, K']
# Beebe Richard, ropemaker Kentn Flushing av
# [', merchant 1']
# [', merchant, 1']
# Beabe Silas R, merchant 137 Front N Y h 116 Johnson
# [', pilot 3']
# [', pilot, 3']
# Beebe Theophilus, pilot 36 Tillary
# [', hatter 1']
# [', hatter, 1']
# Beebe William H, hatter 156 Broadway N Y h Clinton av
# [', pastor P']
# [', pastor, P']
# Beecher Rev Henry Ward, pastor Plymouth Ch h 197 AYash-
# [', Mansion H']
# [', Mansion, H']
# Beecher William A, Mansion House 121 Hicks
# [', merchant 6']
# [', merchant, 6']
# Beekman A J, merchant 61 Liberty N Y h 73 Livingston ington
# [', tailor G']
# [', tailor, G']
# Beers Henry A, tailor Gold c Fulton av
# [', grocer 1']
# [', grocer, 1']
# Beers John H, grocer 158 Prospect
# [', musician 6']
# [', musician, 6']
# Beers Lewis, musician 65 Poplar
# [', grocer J']
# [', grocer, J']
# Behm John, grocer Johnson c Adams
# [', shoemaker W']
# [', shoemaker, W']
# Beine William, shoemaker Willow place c State
# [', porter 5']
# [', porter, 5']
# Belfe John R, porter 56 Baltic
# [', coachman 1']
# [', coachman, 1']
# Belford Matthew, coachman 103 Atlantic
# [', optician N']
# [', optician, N']
# BEKKNAI’ ROFUS R, optician NYh 108 Hudson av
# [', commander U']
# [', commander, U']
# Bell Charles H, commander U s N Flushing av n Navy
# [', seaman 1']
# [', seaman, 1']
# Bell Jacob, seaman 16 Myrtle av
# [', carpenter V']
# [', carpenter, V']
# Bell John A, carpenter Van Brunt n Dikeman Red Hook
# [', clerk N']
# [', clerk, N']
# Bell John, clerk NYh 125 High
# [', rigger 2']
# [', rigger, 2']
# Bell Joseph, rigger 219 Front
# [', bookeeper 5']
# [', bookeeper, 5']
# Bell Thomas, bookeeper 58 Fulton
# [', carpenter A']
# [', carpenter, A']
# Bell William, carpenter Atlantic c Bond
# [', carman P']
# [', carman, P']
# Bell William, carman Plymouth n Pearl
# [', brushmaker 3']
# [', brushmaker, 3']
# Bellamy Joseph, brushmaker 357 Pearl NYh 57 Johnson
# [', locksmith 2']
# [', locksmith, 2']
# Bellamy William, locksmith 217 Pearl
# [', druggist G']
# [', druggist, G']
# BELLINGHAM JOHN, druggist Gold c Prospect
# [', tanner 3']
# [', tanner, 3']
# Beman William, tanner 35 Navy n Park av
# [', printer Y']
# [', printer, Y']
# Benjamin Alfred, printer YVyckoff nBond
# [', physician I']
# [', physician, I']
# Benjamin H L, physician IOS Clinton c State
# [', grocer 1']
# [', grocer, 1']
# Benjamin John H, grocer 155 Nassau
# [', mercht 3']
# [', mercht, 3']
# Benjamin Wrn, mercht 31 Broad N Y h Cheeverpln Harri-
# [', physician 1']
# [', physician, 1']
# Benedict William C, physician 195 Atlantic
# [', blacksmith F']
# [', blacksmith, F']
# Bennett Benjamin, blacksmith Furman n State h Carlton n
# [', accountant 2']
# [', accountant, 2']
# Bennett Benjamin, accountant 222 Pearl N Y h 144 Jay
# [', farmer 3']
# [', farmer, 3']
# Bennett Charles, farmer 3d av c 29th st Gowanus
# [', farmer 3']
# [', farmer, 3']
# Bennett Cornelius, farmer 3d av n 27th st Gowanus
# [', physician 1']
# [', physician, 1']
# Bennett George I, physician 195 Washington h 182 Adams
# [', office 1']
# [', office, 1']
# Bennett George L, office 102 Front h S3 Henry
# [', merchant S']
# [', merchant, S']
# Bennett Henry, merchant Sl Water N Y h State n Bond
# [', butcher S']
# [', butcher, S']
# BENKETT JAMES, butcher Smith c Douglass
# [', milkman P']
# [', milkman, P']
# Bennett James, milkman Pacific op Washington av
# [', farmer G']
# [', farmer, G']
# Bennett James, farmer Gowanus rd
# [', painter 4']
# [', painter, 4']
# Bennett John, painter 42 Main
# [', carpenter R']
# [', carpenter, R']
# Bennett John Gr, carpenter Raymond n Myrtle av
# [', accountant 1']
# [', accountant, 1']
# Bennett John, accountant 126 Prospect
# [', clerk N']
# [', clerk, N']
# Bennett J, clerk Navy c De Kalb av
# [', physician 1']
# [', physician, 1']
# Bennett J B, physician 13 Cottage row Columbia n Degraw
# [', widow 4']
# [', widow, 4']
# Bennett Margaret L, widow 40 Front c Garrison
# [', sexton 1']
# [', sexton, 1']
# Bennett Nicholas, sexton 100 Gold
# [', tavern H']
# [', tavern, H']
# Bennett Robert, tavern Hamilton av n Atlantic Dock
# [', cooper 1']
# [', cooper, 1']
# Bennett Samuel M, cooper 166 Prospect
# [', fisherman R']
# [', fisherman, R']
# Bennett Thomas, fisherman Red Hook point
# [', bookeeper N']
# [', bookeeper, N']
# Bennett William, bookeeper N Y h 147 Hicks
# [', carpenter 1']
# [', carpenter, 1']
# Bennett William H, carpenter 142 Carll
# [', carpenter C']
# [', carpenter, C']
# Bennett William, carpenter Classon n Myrtle av
# [', milkman 5']
# [', milkman, 5']
# Bennett William, milkman 5th av n Atlantic
# [', carpenter 1']
# [', carpenter, 1']
# Bennett W'illiam, carpenter 130 Myrtle av
# [', tavern J']
# [', tavern, J']
# Bennett Wm & L J, tavern Jamaica rd n Atlantic st
# [', carpenter 1']
# [', carpenter, 1']
# Bennett Wi)liam B, carpenter 18 Lawrence
# [', painter S']
# [', painter, S']
# Benning John, painter Smith c Wykoff'
# [', painter 1']
# [', painter, 1']
# Benning Thomas, painter 141 Atlantic h 108 Pineapple
# [', laborer R']
# [', laborer, R']
# Benning U, laborer Red Hook (and Hicks
# [', merchantN Y']
# [', merchantN, Y']
# Benson Alfred G, merchantN Yh Montague place b Henry
# [', laborer W']
# [', laborer, W']
# Benson John, laborer Water n Dock
# [', currier 9']
# [', currier, 9']
# Benson YVilliam, currier 90 Smith
# [', grocer C']
# [', grocer, C']
# Benson William, grocer Columbia c Summit
# [', coppersmith 1']
# [', coppersmith, 1']
# Benson Wm J, coppersmith 11 Water h 85 Prospect
# [', carman 9']
# [', carman, 9']
# Benstead W''illiam M, carman 90 Navy
# [', florist H']
# [', florist, H']
# Benton R, florist Henry c Hamilton av
# [', merchant 3']
# [', merchant, 3']
# Berdell Robert H, merchant 32 Front NYh Harrison n
# [', First P']
# [', First, P']
# HSergen Alexander, First Place e Court
# [', First P']
# [', First, P']
# Bergen Cornelius, First Place c Court
# [', clerk N']
# [', clerk, N']
# Bergen Elias H, clerk NYh 150 Joralemon
# [', grocer 2']
# [', grocer, 2']
# Bergen George W, grocer 26 Fulton h 15 Poplar
# [', fireman 1']
# [', fireman, 1']
# Bergen John, fireman 120 Prince
# [', alderman 8']
# [', alderman, 8']
# BERGEN JOHN V, alderman 8th Ward 3d av Gowanus
# [', jeweller 1']
# [', jeweller, 1']
# Berkstein Augustus, jeweller 160 William N Y h 56 Adams
# [', tailor W']
# [', tailor, W']
# Berry Adam, tailor Washington av c Fulton av
# [', shipmaster L']
# [', shipmaster, L']
# Berry Charles C, shipmaster Lawrence n Fulton av
# [', butcher C']
# [', butcher, C']
# Berry Edward, butcher Columbia n Amity
# [', packer D']
# [', packer, D']
# Berry George, packer Dean n Powers
# [', tailor T']
# [', tailor, T']
# Berry James, tailor Tillary c Prince
# [', lighterman 6']
# [', lighterman, 6']
# Berry John, lighterman 6S Bridge
# [', farmer G']
# [', farmer, G']
# Berry John, farmer Gowanus lane c 15th st
# [', tailor 5']
# [', tailor, 5']
# Berry John, tailor 51 Main
# [', tailor T']
# [', tailor, T']
# Berry Johnson, tailor Tillary c Prince
# [', painter C']
# [', painter, C']
# Berry Lewis W, painter Carlton e Myrtle av
# [', widow 8']
# [', widow, 8']
# Berry Lavinia, widow 82 Myrtle av (Jay c High
# [', widow A']
# [', widow, A']
# Berry Sarah M, widow Adelphi n Myrtle av
# [', laborer W']
# [', laborer, W']
# Berry Thomas, laborer Warren c Nevin
# [', sailmaker P']
# [', sailmaker, P']
# Berry Thomas, sailmaker Park c Vanderbilt av
# [', blacksmith M']
# [', blacksmith, M']
# Berry William, blacksmith Myrtle av c Sanford
# [', shipmaster L']
# [', shipmaster, L']
# Berry William C, shipmaster Lawrence n Fulton av
# [', shipmaster 8']
# [', shipmaster, 8']
# Bertram William R, shipmaster 85 Livingston
# [', tailor 1']
# [', tailor, 1']
# Bertrand Adolson, tailor 156 Bridge
# [', packer C']
# [', packer, C']
# Bertrand Joseph P, packer Columbia b Atlantic and Stath
# [', widow 3']
# [', widow, 3']
# Besher Maria, widow 331 Gold
# [', laborer 1']
# [', laborer, 1']
# Besseveer John C, laborer 113 Navy
# [', printer 1']
# [', printer, 1']
# Bessey Hiram, printer 125 Hudson av
# [', merchant 2']
# [', merchant, 2']
# Best Richard, merchant 274 Pearl N Y7 h 89 Pineapple
# [', tailor 5']
# [', tailor, 5']
# Betelle Robert, tailor 51 Main
# [', mason 1']
# [', mason, 1']
# Betteison William, mason 17 Atlantic
# [', mason 2']
# [', mason, 2']
# Bettman James, mason 2S6 Hicks n Pacific
# [', shipsmith 1']
# [', shipsmith, 1']
# Betts Charles H, shipsmith 107 Bridge
# [', shipmaster 1']
# [', shipmaster, 1']
# Betts George AV, shipmaster 102 York
# [', widow B']
# [', widow, B']
# Betts Jane E, widow Boerum n Atlantic
# [', school 1']
# [', school, 1']
# Betts Maria E, school 14 Strong Place n Harrison
# [', machinist 1']
# [', machinist, 1']
# Betts Wright C, machinist 105 Front (av n Kent av
# [', physician M']
# [', physician, M']
# Bctts Wm C, physician Myrtle n Carlton av and Flushing
# [', accountant F']
# [', accountant, F']
# Betts William YY, accountant Fulton House 12 Fulton
# [', shoemaker M']
# [', shoemaker, M']
# Bicker Frederick, shoemaker Myrtle av c Spencer (Place
# [', carpenter 2']
# [', carpenter, 2']
# Bickford William, carpenter 26 Lafayette
# [', upholsterer 3']
# [', upholsterer, 3']
# Bicknell Daniel, upholsterer 39 Myrtle av
# [', shipmaster 3']
# [', shipmaster, 3']
# Biddell James, shipmaster 33 Hicks
# [', mason 8']
# [', mason, 8']
# Bid dell John, mason 80 Fulton
# [', accountant 1']
# [', accountant, 1']
# Biden Edward A, accountant 134 Henry
# [', physician W']
# [', physician, W']
# Biers , physician Willoughby c Gold
# [', merchant 4']
# [', merchant, 4']
# Bierworth Leopold, merchant 40 New N Y h 85 State
# [', merchant N']
# [', merchant, N']
# Bigley J E, merchant N Y h 65 Hicks
# [', grocer 5']
# [', grocer, 5']
# Biglow J B, grocer 58 Hicks c Cranberry
# [', merchant N']
# [', merchant, N']
# Bill Charles E, merchant N Y h 119 Columbia n Clark
# [', merchant N']
# [', merchant, N']
# Bingham James, merchant NYh 207 Henry
# [', grocer 2']
# [', grocer, 2']
# Bingham William W, grocer 27th st n 3d av Gowanus
# [', carman D']
# [', carman, D']
# Birch Amos, carman Douglas c Smith
# [', scrivenor 5']
# [', scrivenor, 5']
# Birch George L, scrivenor 5 Mill n Court
# [', carman J']
# [', carman, J']
# Birch Isaac, carman Jamaica road op Portland st
# [', lawyer 6']
# [', lawyer, 6']
# Birch Thomas, lawyer 65 Nassau
# [', laborer C']
# [', laborer, C']
# Bird Patrick, laborer Canton c Tillary
# [', barber 2']
# [', barber, 2']
# Birdsall James A, barber 2 York n James
# [', widow 6']
# [', widow, 6']
# Birdsall Jane, widow 64 Lawrence
# [', ferryman 7']
# [', ferryman, 7']
# Birdsall William H, ferryman 79 Pearl (h 145 Nassau
# [', machinist W']
# [', machinist, W']
# Birkbeck Abraham W, machinist Watcr n Fulton h 110
# [', widow S']
# [', widow, S']
# Birkbeck Eliza, widow Schermerhorn n Boerum
# [', widow 1']
# [', widow, 1']
# Birkbeck Sarah, widow 118 Adams
# [', porter C']
# [', porter, C']
# Birley George, porter Columbia c Warren
# [', laborer B']
# [', laborer, B']
# Birmingham James, laborer Bergen c Smith
# [', laborer 6']
# [', laborer, 6']
# Birmingham John, laborer 6 Tiffany place
# [', grocer C']
# [', grocer, C']
# Birmingham Thomas, grocer Carll n Myrtle av
# [', teamster 4']
# [', teamster, 4']
# Bisseck George, teamster 40 Carlton av
# [', builder 1']
# [', builder, 1']
# Bishop A D, builder 121 Adams
# [', carpenter P']
# [', carpenter, P']
# Bishop Alfred, carpenter Pacific n Underhill av
# [', accountant F']
# [', accountant, F']
# Bishop Charles W, accountant Fulton av c Hoyt
# [', clerk 7']
# [', clerk, 7']
# Bishop Henry, clerk 78 York
# [', painter 4']
# [', painter, 4']
# Bishop James F, painter 4 Linden row Fulton
# [', mason 1']
# [', mason, 1']
# Bishop John, mason 1S7 Concord
# [', clerk N']
# [', clerk, N']
# Bishop Richard, clerk Navy n Nassau
# [', sexton T']
# [', sexton, T']
# Bishop Robert, sexton Trinity Church 250 Adams
# [', clerk P']
# [', clerk, P']
# Bishop Thomas, clerk Phoenix Bank N Y h 175 Adams
# [', merchant 1']
# [', merchant, 1']
# Bissell Edward, merchant 106 Murray NYh Hoytn Dean
# [', baker W']
# [', baker, W']
# Bithell Charles, baker Water n Jay
# [', clerk S']
# [', clerk, S']
# Bitman Godfrey, clerk Sands c Pearl
# [', Emerald H']
# [', Emerald, H']
# Bittelle Michael, Emerald House Columbia n Amity
# [', watchmaker 4']
# [', watchmaker, 4']
# Black G C, watchmaker 42 Fulton N Y h 134 Adams
# [', shoemaker D']
# [', shoemaker, D']
# Black James, shoemaker Duffield c Fulton av
# [', Old B']
# [', Old, B']
# Black P C, widow of William, Old Bridge rd Gowanus
# [', tailoress 1']
# [', tailoress, 1']
# Black Rebecca, tailoress 110 Jay
# [', bootmaker N']
# [', bootmaker, N']
# Black W'illiam, bootmaker Navy n Myrtle av
# [', clerk 4']
# [', clerk, 4']
# Blackett William, clerk 44 Hudson av
# [', cutter 9']
# [', cutter, 9']
# Blackman Homer, cutter 90 Main
# [', phystciau 5']
# [', phystciau, 5']
# Blackmore John, phystciau 5 Cottage place Columbia n Degraw
# [', silversmith 5']
# [', silversmith, 5']
# Blackwell Isaac, silversmith 52 Prince
# [', clothier 1']
# [', clothier, 1']
# Blackwell John P, clothier 179 Broadway NY h 75 Pineapple
# [', widow 1']
# [', widow, 1']
# Blackwood Susannah, widow 119 Court
# [', blacksmith C']
# [', blacksmith, C']
# Blair Adam, blacksmith Columbia n State (Atlantic
# [', distiller O']
# [', distiller, O']
# Blair David, distiller Oxford st n Jamaica rd
# [', tailoress 1']
# [', tailoress, 1']
# Blair Ellen, tailoress 104 Concord
# [', laborer 7']
# [', laborer, 7']
# Blair John, laborer 70 W'ashington
# [', Canal B']
# [', Canal, B']
# Blaisdell Stephen D, Canal Boat Master 71 Main
# [', drugs 1']
# [', drugs, 1']
# Blake Alexander V, drugs 100 William N Y h 86 Clinton
# [', office A']
# [', office, A']
# Blake Anson, office Atlantic c Columbia and Columbia n
# [', clerk 1']
# [', clerk, 1']
# Blake Charles, clerk 178 Washington
# [', accountant 4']
# [', accountant, 4']
# Blake Gardiner, accountant 48 Concord
# [', millinary 1']
# [', millinary, 1']
# Blake Elisha, millinary 102 Middagh
# [', merchant 2']
# [', merchant, 2']
# Blake Hamlin, merchant 2S Broad NYh Montague place c Hicks
# [', clerk 2']
# [', clerk, 2']
# Blake James S, clerk 257 Gold
# [', carpenter L']
# [', carpenter, L']
# Blake John, carpenter Liberty c Sprague Place
# [', grocer 8']
# [', grocer, 8']
# Blake John, grocer 89 Main and 69 Concord c Pearl
# ...
# [', bookstore, 1']
# Willis Thomas, bookstore 109 Myrtle av
# [', laborer U']
# [', laborer, U']
# Willis William, laborer Underhill av n Dean st
# [', boatswain U']
# [', boatswain, U']
# Willmuth George, boatswain U s N h 210 High
# [', tinroofer N']
# [', tinroofer, N']
# Wilsee Homer, tinroofer Nevins n Schermerhorn
# [', baker M']
# [', baker, M']
# Wilsey Joseph, baker Myrtle av n Adelphi st
# [', hatter M']
# [', hatter, M']
# Wilson Alfred, hatter Myrtle c Classon av
# [', carpenter W']
# [', carpenter, W']
# Wilson Andrew, carpenter Warren n Hoyt
# [', distiller S']
# [', distiller, S']
# Wilson Charles, distiller Skillman c Park av
# [', painter 1']
# [', painter, 1']
# 'Wilson Charles, painter 149 Hudson av
# [', shipwright P']
# [', shipwright, P']
# Wilson Charles, shipwright Park av n Portland st
# [', mason 1']
# [', mason, 1']
# W’ilson Charles, mason 19S Myrtle av c Raymond st
# [', barkeeper 1']
# [', barkeeper, 1']
# Wilson Charles M, barkeeper 130 Carll
# [', custom H']
# [', custom, H']
# Wilson Edgar, custom House Bedford road n Classon av
# [', clerk N']
# [', clerk, N']
# YVilsou Edwin, clerk NYh Washington av n Jamaica rd
# [', contractor 1']
# [', contractor, 1']
# YVilson Edward, contractor 145 Willoughby
# [', clerk 2']
# [', clerk, 2']
# Wilson Elijah, clerk 24 Myrtle av
# [', widow 1']
# [', widow, 1']
# Wilson Elizabeth, widow 19S Myrtle av c Raymond st
# [', carman 2']
# [', carman, 2']
# YVilson George, carman 22d st n 5th av Gowanus
# [', miller 3']
# [', miller, 3']
# Wilson Henry, miller 31 Fulton
# [', blacksmith K']
# [', blacksmith, K']
# Wilson Henry, blacksmith Kent n Flushing av
# [', ropemaker 1']
# [', ropemaker, 1']
# Wilson Hiram, ropemaker 198 Myrtle av c Raymond st
# [', grocer N']
# [', grocer, N']
# YVilson James, grocer N Y h 9 Mill
# [', plasterer C']
# [', plasterer, C']
# YVilson John, plasterer Court c Facific
# [', wheelwright 8']
# [', wheelwright, 8']
# Wilson John, wheelwright 86 Poplar
# [', seaman B']
# [', seaman, B']
# Wilson John E, seaman Bridge c Tillary
# [', Greenwood C']
# [', Greenwood, C']
# WILSON JOSEPH, Greenwood Cemetery monumental works
# [', clerk S']
# [', clerk, S']
# Wilson Lewis D, clerk Smith c Wyckoff
# [', widow B']
# [', widow, B']
# Wilson Matilda, widow Bedford rd n Classon av
# [', stevedore 8']
# [', stevedore, 8']
# Wilson Michael K, stevedore 85 Pacific n Smith
# [', laborer F']
# [', laborer, F']
# Wilson Philip, laborer Franklin n Myrtle av
# [', printer 4']
# [', printer, 4']
# WilBon P W, printer 4 Prince
# [', porter H']
# [', porter, H']
# YVilson Richard, porter House Adams c Water
# [', carpenter 1']
# [', carpenter, 1']
# Wilson Richard, carpenter 178 Gold
# [', clerk 5']
# [', clerk, 5']
# Wilson Robert, clerk 55.5 Atlantic
# [', clerk 1']
# [', clerk, 1']
# Wilson Thomas, clerk 151 Sands
# [', printer 4']
# [', printer, 4']
# Wilson Thomas, printer 43 York
# [', mason P']
# [', mason, P']
# Wilson Thomas, mason Pacific n Court
# [', teacher 1']
# [', teacher, 1']
# Wilson William J, teacher 140 Nassau
# [', blacksmith 6']
# [', blacksmith, 6']
# Wilson William, blacksmith 63 Pearl
# [', bookeeper N']
# [', bookeeper, N']
# Wilson William H, bookeeper N Y h 63 Carlton n Myrtle av
# [', laborer 4']
# [', laborer, 4']
# Wilson William, laborer 40 Main
# [', grocer 2']
# [', grocer, 2']
# Wilson William, grocer 227 Gold
# [', shoemaker 2']
# [', shoemaker, 2']
# Wilson William, shoemaker 241 Gold
# [', accountant 7']
# [', accountant, 7']
# 'Wilson William M, accountant 70 Henry
# [', waiter 3']
# [', waiter, 3']
# *Wilson Edward, waiter 3 Hart’s alley n Bridge
# [', waiter 6']
# [', waiter, 6']
# *Wilson George, waiter 6 Fair
# [', laborer 1']
# [', laborer, 1']
# *Wilson Isaac, laborer 19 Hartt’s alley
# [', musician 5']
# [', musician, 5']
# 'Winchell Elbert C, musician 52 Talman (ford av
# [', printer 4']
# [', printer, 4']
# Winchester Ebenezer, printer 44 Ann N Y h Gates n Bed-
# [', shoemaker D']
# [', shoemaker, D']
# Winehart Adam, shoemaker Dean n Court
# [', carpenter 2']
# [', carpenter, 2']
# Winker Henry, carpenter 24 State
# [', shoemaker 2']
# [', shoemaker, 2']
# Winkless William, shoemaker 216 Front
# [', gilder S']
# [', gilder, S']
# Winser James, gilder Sl Adelphi n Myrtle av
# [', bookbinder 5']
# [', bookbinder, 5']
# Winser Wi)liam, bookbinder 51 Adelphi n Myrtle av
# [', seaman 2']
# [', seaman, 2']
# Winslow Albert, seaman 215 Myrtle av n Canton st
# [', laborer 2']
# [', laborer, 2']
# *Winslow Samuel, laborer 2 Hartt’s Alle'y
# [', bookeeper 1']
# [', bookeeper, 1']
# Winsor Nicholas S, bookeeper 153 Jay c Nassau
# [', merchant N']
# [', merchant, N']
# Winter James W, merchant N Y h 43 Joralemon
# [', carman M']
# [', carman, M']
# Winters Conrad, carman Myrtle c Kent av
# [', seaman 1']
# [', seaman, 1']
# Winters Edward, seaman 151 Hudson av
# [', tailor 1']
# [', tailor, 1']
# Winters John, tailor 162 York
# [', shoemaker P']
# [', shoemaker, P']
# Wintoitch John, shoemaker Pearl c Plymouth
# [', brewery C']
# [', brewery, C']
# Wirthschaft Saunders, brewery Classon av b Myrtle & Flush-
# [', nurse I']
# [', nurse, I']
# Wintringham Mrs , nurse ICS Pineapple (ing av
# [', bookseller N']
# [', bookseller, N']
# Wise Henry, bookseller N Y h 69 Fulton
# [', grocer 2']
# [', grocer, 2']
# Wise James L, grocer 233 Fulton N Y h 46 Johnson
# [', carpenterr 3']
# [', carpenterr, 3']
# Wise Martin, carpenterr 384 Hudson av (c High
# [', butcher 3']
# [', butcher, 3']
# Wiseburu Daniel, butcher 3d av n 17th st Gowanus
# [', cooper P']
# [', cooper, P']
# Wiser Adam, cooper Plymouth b Jay and Bridge
# [', agent P']
# [', agent, P']
# YViswess Henry, agent President n Columbia st Red Hook
# [', printer D']
# [', printer, D']
# WITTET MATTHEW, printer Daily Advertiser job office 35
# [', tinsmith M']
# [', tinsmith, M']
# Wolf Maurice, tinsmith Main c Plymouth
# [', laborer C']
# [', laborer, C']
# Wolfe Alfred, laborer Classon b Myrtle & Flushing av
# [', shoemaker F']
# [', shoemaker, F']
# Wolfe Thomas, shoemaker Flushing n Division av
# [', shoemaker H']
# [', shoemaker, H']
# W*ollensack Matthew, shoemaker Hudson av c Tillary st
# [', grocer H']
# [', grocer, H']
# Wolter Louis, grocer Harrison c Hicks
# [', merchant 2']
# [', merchant, 2']
# Wood A M, merchant 213 Fulton h NY
# [', widow 7']
# [', widow, 7']
# Wood Ann, widow 70 Bridge
# [', marketman 2']
# [', marketman, 2']
# Wood Charles, marketman 27 Willow
# [', merchant N']
# [', merchant, N']
# Wood Charles B, merchant N Y h 140 Sands
# [', cabinetmaker C']
# [', cabinetmaker, C']
# Wood Cornelius, cabinetmaker Carlton n Myrtle av
# [', marketman P']
# [', marketman, P']
# Wood Daniel, marketman Park n Vanderbilt av
# [', laborer 3']
# [', laborer, 3']
# Wood George, laborer 38 Hudson av
# [', distiller F']
# [', distiller, F']
# Wood Henry, distiller Franklin n Park av (Park av
# [', distillers S']
# [', distillers, S']
# Wood H & J J & Co, distillers Skillman st b Flushing and
# [', clerk C']
# [', clerk, C']
# Wood Isaac, clerk City Bank NY h Clermont st n Myrtleav
# [', milkman M']
# [', milkman, M']
# Wood Israel, milkman Myrtle n Classon av
# [', tailor K']
# [', tailor, K']
# Wood Jarnos, tailor Kent n Myrtle av
# [', marketman 2']
# [', marketman, 2']
# Wood Jarvis, marketman 282 Pearl
# [', porter A']
# [', porter, A']
# Wood John, porter Adams c Plymouth
# [', machinist M']
# [', machinist, M']
# Wood John, machinist Myrtle av n Raymond st
# [', milkman F']
# [', milkman, F']
# Wood John J, milkman Franklin n Myrtle av
# [', milkman N']
# [', milkman, N']
# Wood Jonathan, milkman Nostrand n DeKalb av
# [', steward U']
# [', steward, U']
# Wood Joseph, steward U s N 147 Prospect
# [', drygoods S']
# [', drygoods, S']
# Wood & Lewis, drygoods S13 Fulton op Clinton
# [', marketman 1']
# [', marketman, 1']
# Wood Lawrence, marketman 120 Duffield
# [', laborer W']
# [', laborer, W']
# Wood L, laborer Wolcott st Red Hook
# [', widow 3']
# [', widow, 3']
# Wood Mary Ann, widow 30 Hicks (turnpike
# [', of A']
# [', of, A']
# Wood Miles, farmers’ retreat junc, of Atlantic and Flatbush
# [', carman 1']
# [', carman, 1']
# Wood Moses, carman 166 Johnson
# [', widow 6']
# [', widow, 6']
# Wood Mrs , widow 67 Concord
# [', merchant 2']
# [', merchant, 2']
# Wood M Q, merchant 269 Front NYh Court n Union
# [', merchant 7']
# [', merchant, 7']
# Wood Ransom E, merchant 72 Water st NY h 58 Harrison
# [', rigger 2']
# [', rigger, 2']
# Wood Samuel, rigger 250 Marshall
# [', bookseller 2']
# [', bookseller, 2']
# Wood Samuel S, bookseller 261 Pearl st NY h 93 Columbia
# [', mason B']
# [', mason, B']
# Wood Smith, mason Bridge n Fulton av
# [', rigger 3']
# [', rigger, 3']
# Wood Thomas, rigger 3 Hudson av
# [', bootmaker 4']
# [', bootmaker, 4']
# Wood William, bootmaker 433 Hudson av
# [', tailor C']
# [', tailor, C']
# Wood William, tailor Canton st n Myrtle av
# [', painter 2']
# [', painter, 2']
# Wood William, painter 258 Jay c Myrtle av
# [', machinist 3']
# [', machinist, 3']
# Woodward George M, machinist 3 James
# [', mason 3']
# [', mason, 3']
# YVoodbury Benjamin, mason 311 Myrtle av n Canton
# [', shoemaker H']
# [', shoemaker, H']
# Woodhead George, shoemaker Hamilton av n Penny bridge
# [', grocer N']
# [', grocer, N']
# YVoodhull Gilbert C, grocer N Y h 44 Nassau
# [', grocer N']
# [', grocer, N']
# Woodhull Smith, grocer N Y h 7 Willow
# [', proprietor L']
# [', proprietor, L']
# WOODMAN HXRRT, proprietor Livingston house 27 Atlantic
# [', builder S']
# [', builder, S']
# Woodruff Ezra, builder Stanton c Concord c Columbia
# [', confectionary 7']
# [', confectionary, 7']
# Woodruff Elizabeth, confectionary 70 Bridge
# [', widow D']
# [', widow, D']
# Woods Catherine, widow Dikeman st Red Hook
# [', laborer C']
# [', laborer, C']
# Woods Cornelius, laborer Carll n Willoughby
# [', laborer A']
# [', laborer, A']
# Woods James, laborer Amity n Willow
# [', laborer W']
# [', laborer, W']
# W'oods W'illiam, laborer Water op Little
# [', laborer K']
# [', laborer, K']
# Woodsinker Adam, laborer Kent n Flushing av
# [', shoemaker 1']
# [', shoemaker, 1']
# Woodward Samuel, shoemaker 11 State
# [', jeweller 1']
# [', jeweller, 1']
# Woodwin Thomas, jeweller 16 Talman
# [', sashmaker S']
# [', sashmaker, S']
# Woodworth George H, sashmaker Smith n Pacific
# [', butcher 1']
# [', butcher, 1']
# Woolley Edward A, butcher 124 High h 217 Fulton c
# [', accountant 1']
# [', accountant, 1']
# Woolley John C, accountant 149 Nassau (Sprague place
# [', clerk 2']
# [', clerk, 2']
# Woolsey Elijah, clerk 24 Myrtle av (ton c Myrtle av
# [', carpenter N']
# [', carpenter, N']
# Woolsey Jarvis, carpenter Navy n Myrtle av
# [', merchant 5']
# [', merchant, 5']
# Woolsey John R, merchant 51 W’illoughby
# [', widow 2']
# [', widow, 2']
# Woolsey Sarah, widow 257 Gold
# [', merchant 1']
# [', merchant, 1']
# Worthington Anthony, merchant 142 Hicks
# [', merchant 1']
# [', merchant, 1']
# Worthington Asa, merchant 142 Hicks
# [', grocer 1']
# [', grocer, 1']
# Worthington Solomon, grocer 107 Atlantic h 32 Garden
# [', grocers 1']
# [', grocers, 1']
# Worthington & Thompson, grocers 107 Atlantic
# [', shipwrights R']
# [', shipwrights, R']
# Wortman & Hunterley, shipwrights Red Hook point
# [', shipwright W']
# [', shipwright, W']
# Wortman Isaac, shipwright Wolcott st Red Hook
# [', carpenter R']
# [', carpenter, R']
# Wortman James H, carpenter Raymond st n Myrtle av
# [', clerk N']
# [', clerk, N']
# Wosdrow S Alonzo, clerk N Y h Warren n Bond
# [', carpenter 2']
# [', carpenter, 2']
# Wright Abraham S, carpenter 24 Front
# [', merchant N']
# [', merchant, N']
# Wright Amasa, merchant N Y h 115 Henry
# [', druggist C']
# [', druggist, C']
# Wright Chauncey M, druggist Columbia c Sackett
# [', carpenter 4']
# [', carpenter, 4']
# Wright Cornelius, carpenter 411 Hudson av
# [', clerk 1']
# [', clerk, 1']
# Wright David, clerk 169 Prospect
# [', milliners 3']
# [', milliners, 3']
# Wright E & H, milliners 37 Pineapple
# [', widow 1']
# [', widow, 1']
# Wright Mrs D F, widow 166 Fulton
# [', tailor M']
# [', tailor, M']
# Wright Henry, tailor Myrtle av n Steuben st
# [', stereotyper 1']
# [', stereotyper, 1']
# Wright James G, stereotyper 156 Bridge
# [', grocer 1']
# [', grocer, 1']
# Wright John, grocer 162 Myrtle av
# [', guager 1']
# [', guager, 1']
# Wright Joseph W, guager 11 Degraw
# [', widow 8']
# [', widow, 8']
# Wright MrsL A, widow 84 Henry
# [', tailor 1']
# [', tailor, 1']
# Wright Patrick, tailor 143 Tillary (h 242 Marshall
# [', widow 1']
# [', widow, 1']
# Wright Susan R, widow 182 York
# [', milkman M']
# [', milkman, M']
# Wright Thomas, milkman Myrtle av c Skillman st
# [', carpenter 1']
# [', carpenter, 1']
# Wright Thomas, carpenter 19 Mill
# [', painter 7']
# [', painter, 7']
# Wright Thomas H, painter 74 Duffield
# [', merchant N']
# [', merchant, N']
# Wright William, merchant N Y h 85 Henry
# [', salesman 1']
# [', salesman, 1']
# Wright William, salesman 105 Fulton
# [', carpenter 1']
# [', carpenter, 1']
# Wright William S, carpenter 165 Johnson
# [', laborer H']
# [', laborer, H']
# Wright Garret, laborer Hunterfly rd n railroad Bedford
# [', painter 2']
# [', painter, 2']
# Wrightner William, painter 2.8 Chapel
# [', cartman 5']
# [', cartman, 5']
# Wrinkle Christopher, cartman 5 Harper court Jay st
# [', brewer W']
# [', brewer, W']
# Wunchenmeyer Frederick, brewer Walworth st n Myrtle av
# [', broker 1']
# [', broker, 1']
# Wyckoff' John N, broker 1U9 Wall N Y h 33 Livingston
# [', broker N']
# [', broker, N']
# Wyckoff'Peter, broker NYh 102 Hicks
# [', cartman L']
# [', cartman, L']
# Wyckoff Simon P, cartman Livingston c Hoyt
# [', widow H']
# [', widow, H']
# Wyckoff Sarah, widow Hudson av c Sands
# [', physician 3']
# [', physician, 3']
# Wyckoff Van Brunt, physician 3d av e Middle st Gowanus
# [', cutter 2']
# [', cutter, 2']
# YVygant Anning, cutter 201 Bridge
# [', musician 4']
# [', musician, 4']
# 'Wyman William, musician 43 Prospect
# [', proprietor M']
# [', proprietor, M']
# Yale E R, proprietor Mansion House 121 & 123 Hicks
# [', painter 2']
# [', painter, 2']
# Yates John, painter 267 Washington
# [', shoemaker 1']
# [', shoemaker, 1']
# Yates John, shoemaker 109 Concord
# [', L 1']
# [', L, 1']
# YATES J G, L 1 coal yard Pearl e Prospect h 106 Pearl
# [', mason 6']
# [', mason, 6']
# Yeaman Robert, mason 61 Concord
# [', clerk N']
# [', clerk, N']
# Yellott John J, clerk NYh 143 Sands
# [', clerk 1']
# [', clerk, 1']
# Yellott William, clerk 124 Prospect (lemon
# [', carman N']
# [', carman, N']
# Yoeman Bernard, carman Navy n Bolivar
# [', farmer 1']
# [', farmer, 1']
# Yerks Isaac, farmer 120 Sands
# [', carman 1']
# [', carman, 1']
# Yerks James, carman 1G1 York
# [', laborer 2']
# [', laborer, 2']
# Yerks Patrick, laborer 238 Hudson av
# [', laborer H']
# [', laborer, H']
# York James, laborer Hamilton av n Penny Bridge
# [', grocer N']
# [', grocer, N']
# York Joseph, grocer Navy n Myrtle av
# [', mason V']
# [', mason, V']
# York Patrick, mason VanBrunt st Red Hook
# [', plasterer 8']
# [', plasterer, 8']
# Young Alexander, plasterer 85 Cranberry
# [', hatter 3']
# [', hatter, 3']
# Young A, hatter 365 Hudson av
# [', laborer H']
# [', laborer, H']
# Young David, laborer Hamilton av n Court
# [', clerk 7']
# [', clerk, 7']
# Young Francis, clerk 76 Johnson
# [', grocer 1']
# [', grocer, 1']
# Young Henry D, grocer 1 Atlantic h 75 Middagh
# [', mason W']
# [', mason, W']
# Young Henry S, mason Washington n Fulton av
# [', lawyer B']
# [', lawyer, B']
# Young Isaac, lawyer Bway c John NYh Atlantic c Powers
# [', hatter F']
# [', hatter, F']
# Young Jacob, hatter Flushing n Classon av
# [', cooper 1']
# [', cooper, 1']
# Young James N, cooper 155 Gold
# [', sailmaker 1']
# [', sailmaker, 1']
# Young James, sailmaker 186 Nassau
# [', importer 5']
# [', importer, 5']
# Young John, importer 57 William N Y h 18 Cottage row
# [', packer 3']
# [', packer, 3']
# Young John, packer 39 Wyckoff
# [', plasterer 2']
# [', plasterer, 2']
# Young John, plasterer 25 Main
# [', tailor 1']
# [', tailor, 1']
# Yroung Joseph W, tailor 196 Myrtle av
# [', dressmaker 9']
# [', dressmaker, 9']
# Young Mrs , dressmaker 95 Cranberry
# [', builder L']
# [', builder, L']
# Young Nathan, builder Livingston n Smith
# [', grocers 1']
# [', grocers, 1']
# Young & Williams, grocers 1 Atlantic
# [', shoemaker C']
# [', shoemaker, C']
# Young Philip, shoemaker Carlton n Park av
# [', shoemaker N']
# [', shoemaker, N']
# Young Samuel, shoemaker Navy n Lafayette
# [', shipwright 1']
# [', shipwright, 1']
# Young Samuel, shipwright 19 Talman
# [', engineer P']
# [', engineer, P']
# Young Thomas, engineer Plymouth n Little
# [', laborer 9']
# [', laborer, 9']
# Young Thomas, laborer 94 Livingston
# [', shoedealer 4']
# [', shoedealer, 4']
# Young William, shoedealer 41 Cortlandt NY h 2 Degraw
# [', laborer 9']
# [', laborer, 9']
# *Young Francis W, laborer 90 Front
# [', plasterer 2']
# [', plasterer, 2']
# Younie James, plasterer 269 Adams
# [', bootmaker 7']
# [', bootmaker, 7']
# Zeller Sohn, bootmaker 73 Atlantic c Hicks
# [', carman N']
# [', carman, N']
# Zindel Leopold, carman Navy nTillary
# [', porter 2']
# [', porter, 2']
# Zwergius Julius, porter 287 Adams

# %% [markdown]
# ## Divide records into different sections based on first letter

# %%
import re

d = {}
value = []
i = 0
for line in data:
  line = line.strip()
  if line:
    if len(line) < 3: 
      # 1850 BK data is not split by '***' instead it is split by 'B, C, D'
      if bool(re.match("([A-Z])", line)) == True: # Removed \. because this dataset does not have that
        # save previous value
        if value:
          if value[0] == "'":
            value = value[1:]
          d[key] = value
        
        key = line
        value = []
    else:
      value.append(line)

# %%
# Check if function above works
len(d)
# Out:
# 25

# %% [markdown]
# ## Combline lines that belong to the same record
#
# Criteria:
#
# 1) First letter of next line not equal to the initial letter in this section
#
# 2) Special cases in the start of next line: B’klyn, B'way, E., W.

# %%
for key,value in d.items():
  initial = key[0]
  new_value = []
  n = len(value)
  i = 0
  
  while i < n:
    if i < n-1:
      if (value[i+1][0] != initial and value[i+1][0] != "*") or (value[i+1][0:2] in ["B’", "E.", "W."]) or (value[i+1][0:2] == ". "):
        if value[i][-1] == "-":
          s = value[i][:-1] + value[i+1]
        else:
          s = value[i] + ' ' + value[i+1]
        new_value.append(s)
        i += 2
      else:
        new_value.append(value[i])
        i += 1 
    else:
      if value[i][0] == initial:
        new_value.append(value[i])
      i += 1
  
  d[key] = new_value

# %%
# remove "(see adv...."
for key,value in d.items():
  n = len(value)
  for i in range(n):
    ls = value[i].split()
    n2 = len(ls)
    for j in range(n2):
      if "see" in ls[j]:
        value[i] = ' '.join(ls[:j])
        break

# %% [markdown]
# ## Identify business vs person records
#
# Made an update on 27/03/20 to change the index notation.
#
# * The first letter of Company names were being removed by the function
#     * ZUCCA BROTHERS
#     * ARNAULT PETER
#     * APPELL JACOB
#     * APPLETON’S AMERICAN CYCLOPG5DIA
#     * BURTON A. B

# %%
# add an index to each record
# in another dictionary, for each index specify whether it's business or person record
index = 1
d_bp = []
for key,value in d.items():
  n = len(value)
  for i in range(n):
    ls = value[i].split()
    if ls:
      if ls[0][0] == "*" or (len(ls[0]) > 1 and ls[0].isupper()): # Upper case as well
        value[i] = value[i][0:] # Changed from [0:] to [1:]
        d_bp.append([str(index), "b"])
      else:
        d_bp.append([str(index), "p"])
    
      value[i] = str(index) + "\t" + value[i]
      index += 1

# %% [markdown]
# ## Save files

# %%
file = open("input/1850/nypl_1850_bk_starred_clean.txt", "w")
for key,value in d.items():
  file.write(key + '\n')
  for record in value:
    file.write(record + '\n')
  file.write('\n')

file.close()

file2 = open("input/1850/bk_index_business_person.txt", "w")
for item in d_bp:
  file2.write(item[0] + ' ' + item[1] + '\n')
  
file2.close()
